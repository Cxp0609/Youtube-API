# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key='AIzaSyA2Ul6y5si8BqkydGb5TdDzwRKhUw8IyCU'
#channel_id='UCnz-ZXXER4jOvuED5trXfEA'#Null code
#the following are the channel ids found within the source code
channel_ids=['UC0cd_-e49hZpWLH3UIwoWRA',#Professor Dave Explains     contains various college level subect such as math English lating sciece Phsycology etc.    //Note comments are blocked on some videos meaning they have to be ommited in the statics for this channel
             'UCdngmbVKX1Tgre699-XLlUA',#TechWorld with Nana      Professional tips for a carrer in Computer Science/Eingeneering with cousre on common tools used
             'UC4SVo0Ue36XCfOyb5Lh1viQ',#Bro Code      Contains courses on programming languages
             'UCEWpbFLzoYGPfuWUMFPSaoA', #The Organic Chemistry Tutor    College Level Math/Science Channel    
             'UCWv7vMbMWH4-V0ZXdmDpPBA']#Programming with Moash   Miscellaneous programming tips and courses

youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# Function to get Channel Statistics

# %%
def get_channel_stats(youtube, channel_ids):
     all_data=[]
     request = youtube.channels().list(
          part='snippet,contentDetails,statistics',
          id=','.join(channel_ids))
     response = request.execute()#Null code

     for i in range (len(response['items'])): # gets desired content from each item in channel_ids
          data = dict(Channel_name = response['items'][i]['snippet'] ['title'], 
                    Subcribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics'] ['viewCount'],
                    Total_videos = response['items'][i]['statistics'] ['videoCount'],
                    playlist_id = response ['items'][i]['contentDetails'] ['relatedPlaylists']['uploads'])#gets upload id
          all_data.append(data)

     return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_data=pd.DataFrame(channel_statistics)
channel_data
# Out:
#                   Channel_name Subcribers       Views Total_videos  \
# 0                     Bro Code    2150000   113872447          831
# 1          TechWorld with Nana    1130000    60105140          123
# 2      Professor Dave Explains    3290000   333759920         1585
# 3        Programming with Mosh    4140000   214718312          235
# 4  The Organic Chemistry Tutor    8380000  1299765352         2830
#
#                 playlist_id
# 0  UU4SVo0Ue36XCfOyb5Lh1viQ
# 1  UUdngmbVKX1Tgre699-XLlUA
# 2  UU0cd_-e49hZpWLH3UIwoWRA
# 3  UUWv7vMbMWH4-V0ZXdmDpPBA
# 4  UUEWpbFLzoYGPfuWUMFPSaoA

# %%
channel_data['Subcribers'] = pd.to_numeric(channel_data['Subcribers'] )
channel_data['Views'] = pd.to_numeric(channel_data['Views'] )
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'] )

# %%
channel_data.dtypes
# Out:
# Channel_name    object
# Subcribers       int64
# Views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %% [markdown]
# The following are just graphs and charts used to test outputs

# %%
#sns.set(rc={'figure.figsize':(10,8)})
#ax = sns.barplot(x='Channel_name', y='Subcribers', data=channel_data)

# %%
#ax = sns.barplot(x='Channel_name', y='Views', data=channel_data)

# %%
#ax = sns.barplot(x='Channel_name', y='Total_videos', data=channel_data)

# %% [markdown]
# Function to get video ids

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=="Professor Dave Explains", 'playlist_id'].iloc[0] #the channel_name has to be changed to a valid name found in the channel_id
playlist_id #this is the id of the playlist that contains all videos on a channel
# Out:
# 'UU0cd_-e49hZpWLH3UIwoWRA'

# %%
def get_video_ids(youtube, playlist_id):

    request = youtube.playlistItems().list(
            part='contentDetails',
            playlistId = playlist_id,
            maxResults = 50)#results per page
    
    response = request.execute()#returns json formaat file

    video_ids = []
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True

    while more_pages:#this loop checks if there are anymore videos on the channel
        if next_page_token is None: 
            more_pages =False
        else:
            request = youtube.playlistItems().list(part='contentDetails',
            playlistId = playlist_id,
            maxResults = 50,#results per page
            pageToken = next_page_token)

            response = request.execute()

            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')



    return (video_ids) #returns the id of every video in the youtube channel

# %%
video_ids = get_video_ids(youtube, playlist_id)

video_ids #outputs the id of every youtube video found in a channel
# Out:
# ['HGcpUxl_9Vg',
#  'q8tn2BBDovg',
#  'xU8H_Fh-TAE',
#  '3wW17u8iNe8',
#  'OVWf45FKr38',
#  'tfm9q4UoQBI',
#  'Fy4Gvlnc1aA',
#  'hSDv2G_I3tc',
#  'OgaHuT-YOaw',
#  'qHa8tywH0DU',
#  'dXqf6F8qlAE',
#  'iqS8jjYOHzc',
#  'r4nMYvqWRFE',
#  'pQOCybcSnug',
#  '4J3fA8iICTE',
#  'za-6Oa3m3Y4',
#  'QJweTMp3kRs',
#  'KXdWnkqzwvI',
#  's2JjHDZDdRE',
#  'GmtZUu2MCWw',
#  'I56ziqOCeXM',
#  'r7_HOZHOi1w',
#  'GtUi3oG3g9Q',
#  'o_tgYVq_c0o',
#  'IWR2HRc5VUE',
#  'OaeZSADcBlg',
#  'E1tztcicy-4',
#  'ggWa_GdFiR0',
#  'UubuLnpZSF8',
#  'aaL9KVbthPE',
#  'Tn5YYkezDko',
#  'kAHfYJqGNxA',
#  'qTWhB3YivLY',
#  'lZpg_BmOLo8',
#  'EaANzjL6MiY',
#  '2QPjqLeVABU',
#  'OyyszruMku4',
#  'yubcXyC9xeA',
#  'slQBujN2E_s',
#  'zSbCkkcrYGI',
#  'dUckiWXr7-I',
#  'J9fAs4x3xs8',
#  'JUtprb8wEIU',
#  'h7R9wsoOO2I',
#  '0VGPC_ICtvw',
#  'iB2MxzmjivI',
#  'S8lfpuVV0og',
#  's7xufkw1hh0',
#  'rdGetYtBVZw',
#  'rdSJZDLfQRY',
#  'J1UykhhE0wo',
#  'CFVLnW8GsL4',
#  'dGHLqaiaTGA',
#  'lXaxLKbm200',
#  'Zxlg31pw1EI',
#  'ODwkLhDOe60',
#  'KyVm6Z9d-LU',
#  'onxEundvmYs',
#  'XNm-kN737fo',
#  'C0X0JX2hXVk',
#  'XlIEzQhBpvQ',
#  '3DiCT5BDIGw',
#  'MD9URKV5MRA',
#  'IjhREjVS5Nk',
#  'pDw9KW52BRQ',
#  'evBiIO6fuHI',
#  'ATG2l8uy8n8',
#  'YKSyWqcKing',
#  'mTqZ8RPS-j8',
#  'tEdZPPWQT-g',
#  'PqducCN9JhE',
#  'c7urAoGPWis',
#  'R0RlRDj-XJs',
#  'AwAhAiQp83k',
#  '3_2LqixG9Cw',
#  '0pbrLnuGX-8',
#  'PXzuqgi3n-o',
#  'Ne8R_k0iJHU',
#  'sDqVTLf3SCA',
#  'nFWHQ99hvf0',
#  'oXx25Jg7q44',
#  'iU8cgQeYnso',
#  'tMVq4Ou7lDA',
#  'QX3lIiyJo54',
#  'z8I_itpjXQY',
#  '1uGcZQm3oaU',
#  'JE1W8PssybE',
#  'RBCJVC2LGhE',
#  'WTnfh2ebh0o',
#  'Ob3rPYttSTY',
#  'qCXupXXXncM',
#  'kfjWxXIPTq8',
#  'zmYYydrokDQ',
#  '0UjGyBO9f68',
#  'St8dbdyev7M',
#  'Hhfg_-y_Yb0',
#  'DYahtF5weHI',
#  'TUWHuDbFEsA',
#  'Om1dviFEi3M',
#  'dh8R2WdHBQg',
#  'lWAyfr3gxMA',
#  'RSC60uBc9GI',
#  'v8dgVIGmOmg',
#  'AfqC_3zRGaA',
#  'KXVTmDU8358',
#  'KmBeotLa9P0',
#  'S1FpUw4D8UM',
#  'LD2RnVcYyhY',
#  'UUe7CFEBDtc',
#  'tvmyg3k2knI',
#  '1JpzY1oEDsw',
#  'eMERkMcX5zg',
#  'coLPU9uKCc0',
#  'UBfEhIJLYfY',
#  'oK6RI2fFuYQ',
#  '512F1ptD4YU',
#  'J8hzu0Oq-G4',
#  '50I4Ds8Xfgc',
#  'oS2eIQQutWo',
#  '9uxIUpr9pvk',
#  'bWILaM_JFFI',
#  'Nnq9ejUwaZc',
#  'VSJmXGuufwI',
#  'd8YhKI5qcfg',
#  '9LZ635q2Ukk',
#  'vbThzgfCYys',
#  'jPfSPNKxv2s',
#  'PPvZNcV8Jvk',
#  'p88PQNp5ME4',
#  'W4iXlGCwLN0',
#  'kJTWaJ7Knp0',
#  'ODgYbmmgOss',
#  'JiGKh00oHlA',
#  'qKxffIrcECg',
#  'qmpbnpMTzYQ',
#  'R3t42yKDtZI',
#  'dOYDu0zOxL4',
#  'AjTEKPonnYo',
#  'CaFrQGmsz0I',
#  '6OhAA2LwoMw',
#  'sRP3mwQ-NNA',
#  '_s5xq6XOOHI',
#  '705DHheuG6w',
#  '-WxG3TeNFVo',
#  'Hi5vH5RIiRw',
#  'Ydy0Nkq4qOE',
#  'm4VwgFX1Uv4',
#  'Fy_xQnHE2c4',
#  '2nHSGfvLDSQ',
#  'NYF_SgMsxmk',
#  'KFFrZsuGmbQ',
#  'RpUv3GeyMoo',
#  'xglo2n2AMGc',
#  'w9r7Xcahyvs',
#  'gTYpVAfQNg8',
#  'YScIBsI6RxY',
#  '4NYVBtt0ioI',
#  'FZUYxFFxZjE',
#  '7wXYcdBowFo',
#  'VjWKIUg3UNI',
#  'TwhLMK0gD2Q',
#  'K3bU6ymUd9E',
#  'LYUzIf12qac',
#  'C3c4e3lzUKY',
#  '42Jjt2zUh00',
#  'R3qgie64mCE',
#  'iATp8DO3RA8',
#  'v9WTp3FfvyI',
#  '6C_VWMbrqlg',
#  '9JAoLJrKHQc',
#  '7hHXYiCNkgE',
#  'eR2ho7Hmli8',
#  'N_FOmvzDytI',
#  'JN4bxeHjrD4',
#  '9pyPrey3Iuo',
#  'JqD0Ir0MKlw',
#  'LOcjogIjfIA',
#  'Po_isW4a-J0',
#  'Ahwx9D4KoO8',
#  'pqi3bUsEb3g',
#  'xZXYhWHZsrs',
#  'mT_Cm640QnE',
#  'WuRcrOV-0h4',
#  '5lIw_MhirBM',
#  'wDIquIf0g2U',
#  '9k396zy07GI',
#  'DDn7qaqjIOc',
#  'sd8cVCtIRO4',
#  '7KnbPqfeWyQ',
#  '4AoFy-ZPVeM',
#  'TAxapfu5AAM',
#  'VeJz2q0umJE',
#  'RLnwVEAdD28',
#  'RmB6CmtZpOQ',
#  'uKqJbJM-z2w',
#  'GwgxCQL2FLc',
#  '0nkXjVBU7bM',
#  'Ij26p3_JVjo',
#  'L9okFQ9B7pI',
#  'yrToERwQllg',
#  'zGJtIllHSFo',
#  'EhkgJwBj7Hs',
#  'LMSlPJNY2s0',
#  'F7k1f1TiQ5c',
#  '8CJjtGF_AZE',
#  'SnDp-X_orEc',
#  'gUgeEcQsIxE',
#  'IwBnEABIRGQ',
#  'j7Igj8niPmY',
#  'Yo7DPtSY9Ns',
#  'p01hH7_5U4g',
#  'xSXVofnfigo',
#  'LhjqbXPdi3s',
#  'TZh-PHfagDk',
#  'YrYgAFNWDH0',
#  'eC7RHH72m3g',
#  '5Sl1-Y4UUiI',
#  'pYgN-YwZC50',
#  'vOH7y-jKVSY',
#  'NZCtDiXMvCs',
#  'qIw-yFC-HNU',
#  'fyPYgVIQAq0',
#  'GMg_jJ7nX_g',
#  'mpR6sRTRMVE',
#  '1mM9TfEFNf4',
#  'bIXs55QA6Mw',
#  'NlgRcg1dAkc',
#  'nQec4_wjvcA',
#  'oz8q2g2uQDE',
#  'yw9DJjiusr0',
#  'YyqiCHeUpSk',
#  'er3lo_yOY2g',
#  'x8BmbUQoB54',
#  'Ea47Gat0Oec',
#  'r6cjeDcs3uE',
#  'Zt4ywFg6kIE',
#  'fKWX_DKLp5M',
#  'cpshgHJFxOY',
#  'MLumVY06Htw',
#  'WNclwgMSRng',
#  'g6bhEEHK52k',
#  '2kGZu-xjyQY',
#  'JzsmkVUEy0Q',
#  'c_Va0ym_BHE',
#  'Z6D_epfNxQ4',
#  'T36ynMB0ckw',
#  '-gm7ZyVe4hc',
#  'Q781bakoxHw',
#  'aT-Qz-kxufU',
#  '0VB7Uu8Si1U',
#  'NqF1per99lE',
#  'fncTqdhFkBE',
#  'iiU39goAMtw',
#  '9LOndaNwyyA',
#  'NO050D2o1g8',
#  'i7QR8PEadxw',
#  'PWqxR76-Tlg',
#  '8gS5puV8-aI',
#  'VByCLpj-I_s',
#  'XX2j3fP3rbA',
#  'AjeehDwOUCk',
#  'tohXjv4tdQY',
#  'hdatcMbqt_M',
#  'THWcZdhu0x0',
#  '_tmPnH-JkNg',
#  'D9vcioJOUCc',
#  'PR8EjKvZDnw',
#  '4A7X-nfeQUQ',
#  'fGidXCm8om8',
#  'YAm2W99Qm0o',
#  'RxGxZtxXLbk',
#  '0QTkumoJnuU',
#  'Tj78hi1c9Bk',
#  'KvGdllx9pJU',
#  'xVrSO9ThZRY',
#  'G16TuZF1_Os',
#  'Tq1WK6VKnZo',
#  'Wy4TGV-tPd8',
#  'WbeGLoeO5JA',
#  'VSXlNMtZsb8',
#  'znGNXAbSN5k',
#  'Qqdf_26NVW0',
#  'aXCpI8YYvxE',
#  'jT2MoNH67Zo',
#  '9dAcEBXAFoo',
#  '8SQzXyt5UYk',
#  'fcn1mvk33uo',
#  'c9tAuBLA2mI',
#  'NpV4DWL0bSw',
#  'YLpFrcUDitE',
#  '0aWJCAmXkPc',
#  'iFowVwnWYYg',
#  'SmL1sNnEKXc',
#  'rvXq5A-qLWw',
#  'FCJ9XuN2b7E',
#  '8NCoTWfLzPU',
#  '60raZLvVw_Q',
#  'zN5vEo3iTH8',
#  'HwBVL4AT7Wc',
#  'gTeZixVsI9w',
#  'du8LEI7WVHk',
#  'JKx3OjZGoRw',
#  'BX4erEJ1Lxc',
#  'B7sgoKmz01A',
#  'Jr_ylwvxcQg',
#  'TtvSyROolsk',
#  '_CDEOMcm8KE',
#  'G8lqnkaItfQ',
#  'H1lTx5IJdUo',
#  'fYQwUTjZd2M',
#  'YAKC2xQ1c-4',
#  '47w9agU6rQg',
#  'k6MH4K35xiE',
#  'ltT8vr5Wmz8',
#  'OykRnIniC6g',
#  'J56Z3Ky6U2c',
#  'HJooCl9TVvU',
#  'PMFHC2GO-ZA',
#  'DVy3Y-0F5bQ',
#  'R2zElslG_tE',
#  '25eF20yY4pk',
#  'sYfOA5FR6gg',
#  'U-JrTSbUsK0',
#  'ftWa4egNG6A',
#  'flY1B_dIYuY',
#  '0eMFZrsA5DE',
#  'XO3yJkXrE6g',
#  'Q2QSoexGP8M',
#  'Gxv-GFVNNvI',
#  '6L2zcuveYAU',
#  'OS8BqRjO-ZA',
#  'TH9bU7jWRk8',
#  '-z8fExTafPo',
#  'ryNQBxmcOu8',
#  'Oz8WOpNH01w',
#  'D6MGnSd26XE',
#  '81cyHI46zv8',
#  'ugdXW98JKxo',
#  'sNqGpaBRkIs',
#  'g5iHwEVtsq8',
#  'xnuBeCktmNY',
#  'o0Yt6buayZ4',
#  'A11b6tORIcM',
#  '-PWDV9vT_9Q',
#  'iIfmoD-G1qo',
#  '7hIBg_a5rnQ',
#  '4H3dPdONogw',
#  'vLMsCgNVryY',
#  '1Y5vbYHa0E4',
#  'zS6Lro53c-Q',
#  'ZdVAxUfBofw',
#  'h8p8DTHv0hQ',
#  'rNU3ezk_OmM',
#  '-SxxefniyfY',
#  'cw-Wc_KjHgc',
#  '7VCAoyAkdvY',
#  'G-ngcEnq7KE',
#  'NFPHvvJWVAk',
#  'cjbzAJrC8-Y',
#  'ut7La_gNF2I',
#  '-S-mg1LMOAo',
#  'wmyTGE4Ri2s',
#  'QnVTkM80OYA',
#  '3sUs8nso3z0',
#  'mYIB6qqsd3Q',
#  'w75LCj3aLG8',
#  '5yvpsftAZP4',
#  'sAHHK2A1D2w',
#  'NZnqaf2gWcU',
#  'bp86b0oQlMQ',
#  'TL0ZsNHGhsc',
#  'UJJQziuOK7M',
#  'x4qDjP-1d2M',
#  '1TM8mvq_rhU',
#  'MVQGQz-0Xeo',
#  'H84sSTLg9GI',
#  '17xy5-g22hI',
#  'EYBM1t4iQlg',
#  '-q-Gk8MbwR4',
#  'WBGWCeWhOq0',
#  'CXct5-xBLPw',
#  'RwBUgVDeRqw',
#  'KNTu_pqmq2E',
#  'R-zODKWCCWA',
#  'iYqw89gHsE8',
#  'S4q_U86JnTc',
#  '2n_ai-TLSmU',
#  'PdbJ-vnmbPU',
#  'ZwqLCX-TN8c',
#  'oTrnz4Yy5m8',
#  'PNrh9Fv5rWE',
#  's72CB01ICZw',
#  'Kuldv8EwFCc',
#  'm9iYyCRXod0',
#  'Exl3eI3M_kY',
#  'Prey5z8WQiU',
#  'joIX79BMzrc',
#  '9S85CypctJI',
#  '3Tp2lfnA_UI',
#  'WoJhcTdlAhk',
#  'n-ab1YPBdj8',
#  'Zc1NF7aWtkI',
#  'k161h0bcuRg',
#  'GASb0ECxrCs',
#  'Al1pM65k8rw',
#  '10TBCE1g40k',
#  'X2JJ_bzj92c',
#  'ldcpvu2dn1I',
#  'dFxMMSjnIBQ',
#  'aodnQWXYkZ0',
#  '5_C6SgMdmh0',
#  '9uZOLtdIA7Y',
#  'xNK_dzvakL8',
#  '3MCcZLpCaZw',
#  'fpGqFUStcxc',
#  '5sPTDmazgJM',
#  '26UkTow1RRo',
#  'OWTwDpm4ins',
#  '7DuVsDOKUJM',
#  'b0GzncUcArY',
#  'Pq05yrqsQ4k',
#  'Akv0TZI985U',
#  '5qSarYOhD_4',
#  'WCN_gHhdqCA',
#  'PyTdTmU2hOM',
#  'AVYLS8g8SAI',
#  'N5IBDHA--gk',
#  'nYVAK6PgzN0',
#  'vnQFxfkGGq0',
#  '2iw1wOGjm1k',
#  'UIxtzG9E_80',
#  'DDr2M5-REIU',
#  'dD6LcHj3Kgc',
#  'HRxq1Vrf_Js',
#  'SYKnw6em7zE',
#  '63pSwsTJCbs',
#  'he-7vs0BkLE',
#  'iGphAx8pdVM',
#  '9R6wrWYAG7E',
#  'F2COZ97gCVo',
#  'Rtc4oYFR64g',
#  'DkRs6pPJ2k4',
#  'HClsY9AGnqI',
#  'vKYvbZTt5rg',
#  'J_OTc04DVVE',
#  'DWC2lZHaq5c',
#  'fQQacw8WPIY',
#  'eJTIo_MhG3M',
#  '8GMoAG6RX5s',
#  'FVRayGuBzZE',
#  'HPgTCNb684A',
#  'ooqAbda7S9c',
#  'PMVH_PXUa6A',
#  '6c21XMMH5Vg',
#  'qNiOXc6pSBQ',
#  'C3u0ZBv9PjQ',
#  'a9DsKcyUErw',
#  'Rhdmss0-x34',
#  '-eMCDH2zoOc',
#  'VRhciYIL3pA',
#  '6_G_o1KPYyk',
#  'DpNHiR1DIKc',
#  'RxWmdyjR544',
#  'q_rt8GzYcgg',
#  '3zUKX1lOoug',
#  '388TPL5M9us',
#  'YuamvQVXOiY',
#  'GeVFDRnMdUs',
#  'WxzqOcY1R1U',
#  'ZsJ0E6LH8Bs',
#  '-ntOkgo7knY',
#  'pMUbfFRsLmQ',
#  'hbentAZuaYA',
#  't-86dB3JkBw',
#  'jEEqbBrJWRI',
#  'ylz1UwSrpAQ',
#  'mShp0bhC0lQ',
#  'O-B4Q1RlDDY',
#  'YpAXmVz6Q-Q',
#  'NEILW-Pl2vY',
#  'v3lxy4VhJ-k',
#  'ocB9V8Dnb3o',
#  'APkHKOf9rG4',
#  'DcxL7hhVruk',
#  'lRkZ5KfdaGw',
#  'cLK-lEUfwj0',
#  '2CBRoGOFNhI',
#  'l29vbExLSak',
#  'o106KpGUMx0',
#  '-1cfJPEYkkk',
#  'iQX4wmZNapg',
#  'CPcNfQfjjiw',
#  '_qqwq8EmTY4',
#  'yG_Ot9rsNaw',
#  'guht8PUxd64',
#  'SlmfD57TeDk',
#  'rbJ3H13yrTw',
#  'uKLrhp4Kw2A',
#  '32gaaoeBiPU',
#  'IiPL5HgPehs',
#  'dU4dvkB-4GE',
#  '3btNV4z793A',
#  'E4mWEaxUpP4',
#  'l4-DYqS_LbY',
#  'K4qvB7KXAw4',
#  'EeeKxLhTgBo',
#  'bE9avMoRrBA',
#  'J7RC2DKf6rs',
#  's-hpdPTjHzc',
#  '8YFPVs1vurk',
#  'rDHGySBN224',
#  'XyTQYLvPAE8',
#  'yIMz9pkT9xQ',
#  'wiEHjw01P9c',
#  'TG6fxnDqjx0',
#  'jRRzyQ0xygA',
#  'Uc4nq4Lazo4',
#  'UGnsQbe7xcc',
#  'ABNL-5ZS3fE',
#  'wHCBI3yypmE',
#  'Q6FknMOlU_w',
#  'ROfKN0QXMXw',
#  'ZjFL8LtZBzE',
#  '867AUDQ9DQc',
#  'bRnBHml8nto',
#  '9aVLUZV_khU',
#  'sNIcR1PAGIk',
#  '1XIG6Lo5cjg',
#  'G9e0lMAdtiE',
#  'lXclDvD5aHM',
#  'CVXh55gZqNg',
#  'mmttPKZC3r4',
#  'k1T1IdkAcFM',
#  '_TsyUrSkRqU',
#  'wgHx_AFNqF8',
#  'rv6Sq0fmclY',
#  'SYRTIDY8VOE',
#  'vhbGSieEBn0',
#  'XnkKTxf1LHc',
#  'qhyIGt9wrD8',
#  'Fgk9bplNEF8',
#  '-MP_H_D-MYk',
#  'DsW31fbva-M',
#  'kUR98x1tH0c',
#  'j_eFz2R6i40',
#  'RSyvcANRaOE',
#  'cOqMR_yik1I',
#  'jAXLQTcwnTU',
#  '11C4oJebdBo',
#  'QoWzlcbyNWM',
#  'Jf72o6HmVNk',
#  'ghJGnMwRHCs',
#  'EMq_QbyghMU',
#  'cGDNdvg-H1M',
#  'gg_qfPRd-mo',
#  'bU-TXV-N-hk',
#  'F2-ZxJfzNVg',
#  '29OSjXVGKJY',
#  'Uw4xLw669No',
#  'j9ooSSqsB9M',
#  'bRUAIitg1xw',
#  'QB26nwRFUFY',
#  'cFwG1Ct4FTg',
#  '8oodcy8SEBk',
#  'a5pciPcfF48',
#  'BADaEC1sziM',
#  'BJCO97BpYIE',
#  'LkT_6Dp2Z9Y',
#  '3XrTAUhxUWE',
#  'kZ1km9xLfaU',
#  'DZX5AGST8qE',
#  'aQTWor_2nu4',
#  'aEasxr-mgI8',
#  'psZ4gB5HdA0',
#  'SNpLgawkYmE',
#  'qZn1SzWET3A',
#  'ZztpEXSAVrM',
#  'hCKk5pDXKuU',
#  'dRKtsZD0G38',
#  '6b2gZA70xxg',
#  'xnM2hTXd1vE',
#  'n7oklTRgIL4',
#  'XKNbkkRL_Ao',
#  '-EPbylsBuzg',
#  'Eq7sywex3Ts',
#  'j1Krn0kkSUg',
#  'xQiF2ZwI2uo',
#  'QBaCMPBZOW4',
#  'VHgcEvckjtM',
#  'b-z3peN1s1I',
#  'a0G7iyz4McM',
#  'RppUlt7KCPE',
#  'kBlzl0FpeC8',
#  'X89Z3TRnYxw',
#  'S7Ysd7DnVGU',
#  'E61AdIYEBuk',
#  'WOHU2AIRDyI',
#  'G43blvKoY_k',
#  'tR87_75CBtg',
#  'dPvdw2UP7JE',
#  'J3E0Gav45Kw',
#  'plw-ySLS-lI',
#  '9bB-0dt6u-g',
#  'imKTZ18w630',
#  'P4Cqq7NgmUQ',
#  '_IcM3i5l534',
#  '3fTLZTEE7mU',
#  'tQZyurzh5Ms',
#  'Y2dx5ngLimU',
#  'kOKddw5CVGs',
#  '7BG4ZOfDk8M',
#  '7ae_XdFEQDw',
#  'wqKNm_evkYA',
#  'P49nfNOzIy0',
#  '9_ODnibW7qM',
#  '0J-QqDGdprs',
#  'M-qDzKG3RB0',
#  'MXFwL3wfFrE',
#  '2Tq9aMZ87rM',
#  'ma7MVU8sjkI',
#  'MpASCHYzkKE',
#  'tWR3c-GYdo4',
#  'IH636KqlU0c',
#  'eXKThTSnot8',
#  'pyihsgc209Q',
#  'Fe3HZGZCyYE',
#  'wovX7pJGwzs',
#  'zAQt9wk45bE',
#  'Z9LO7Dbqerg',
#  'eN5ROvxpx8Q',
#  'Zi_mQ0sKOfo',
#  'SAM5mcHkSxU',
#  'OvRxDQdAtGc',
#  'YA0r3-ccZDM',
#  '3VxeqgXa02c',
#  'QBYgzJ4ZeNs',
#  'SXbRkRmSicQ',
#  '_FK1VZGiqOk',
#  'OiwyuEG8M4w',
#  'sqiVox2aRxU',
#  'RqCqUEu9nY4',
#  'Uvvf4LcZceU',
#  'Dd-FAyHdpxI',
#  'OBsBtuh-wAk',
#  'JNdfoO_HBEc',
#  'h8c21WIst0U',
#  'zLc_s7NM8pw',
#  '4XqbniWANdE',
#  'LWbQvERL75g',
#  'BTUJyazbJ2Y',
#  'LBB39u8dNw0',
#  'D33ZL-qKi9A',
#  'ePO67uJiXSc',
#  'VSzn-B0w0fE',
#  'jBcenuer5N0',
#  'bsXNinMK-P4',
#  'SixyZ7DkSjA',
#  'l4fFG2utivw',
#  'syzMNaXt9Xw',
#  '1M1wbosKKxg',
#  'ZpWRZarRULE',
#  'Q7lettUm9ag',
#  'zHlp7j3alJA',
#  '5nyQqOHNFCM',
#  'DNdriP9kFiQ',
#  'H8llZJhMk-c',
#  'FZ_qJ695HnQ',
#  'rt-2WQgTLks',
#  'su-fmoZUkF8',
#  'cS6A7I-auf4',
#  'E4-4BZOKAKQ',
#  'MDtOFhQ0Ll8',
#  '5S7_j5xEk2o',
#  'ODYhXWegw0Y',
#  '8YjMLz5imfM',
#  'XbAjOpy3axg',
#  'Up_qu1lT_UA',
#  'vmVdPgkudC8',
#  'wR1yUlJ9CPg',
#  '3Zp5S8ODu9k',
#  'Meaifz6z5Js',
#  'EdAUXAsSrlo',
#  'nOfj9LxA7QY',
#  'AnE9EYgXxpU',
#  'KiQBkg2FT6o',
#  'GGfqkuxbIC0',
#  '7LJHyj0u76w',
#  'z9uk79KnOBk',
#  'jYzlH_GHGCs',
#  '_d-v_faao7E',
#  'N6p0paZ2noA',
#  '4NMjEKuF6FY',
#  'Qh9lCV8-TcY',
#  'd3HIeLAw3BY',
#  '6ybpQrqJWhs',
#  'N88Dzu5k8Pc',
#  'EhTbAP1Iyhk',
#  'hG8U1ImFIAM',
#  'wHiXQt9U3kc',
#  '0zlYQ0VeRQ4',
#  'dwko0IFlzdQ',
#  'UW06euRm09Q',
#  'dVG1dNygOgA',
#  'fAajKkjjLCQ',
#  'S5egQXgBZ6c',
#  '3VOazE6M8Cc',
#  'Hs9Mj2aeop0',
#  'HaVjaxxBTqs',
#  '7LUlwpX48NM',
#  'm-bTWGPZqhk',
#  'T9q-v4lBGuw',
#  'l4vDpMuTpiE',
#  'yh2cjveut1M',
#  'VURzDTCEovE',
#  '_bHqBy92iGM',
#  '19fSG4Skvws',
#  '2iZSHkyLdBE',
#  'lADC0C_WeH0',
#  '8FmLeLJwFNM',
#  'Hv5flUOsE0s',
#  '39VKA8vPXGg',
#  '0tAkOX4O8S4',
#  'EKLIkfgfTyg',
#  'lU8gHrA5QCQ',
#  'PGzT3cTPah8',
#  'se36C6eEte8',
#  'YykFsBxWMbo',
#  'mKnbGnEQO8M',
#  'WFpYXbAfP_I',
#  'J1AXbqhDFuk',
#  '7JopGBx0ZhY',
#  '3McgeF_HnaM',
#  'L1W0q1kEof4',
#  'qL1T4_Dj6n8',
#  'HdYIp3Y-0R4',
#  'I8v5NlG3dSg',
#  'wrtLyLwt51o',
#  'ZnU3M5C2Hcw',
#  '3oLq1VQ6Axg',
#  'ASYI5B0Q6m8',
#  'E3yo_T-JmEg',
#  'IShS60Azqjg',
#  'EakBZqmmfMQ',
#  'JzOouZHde2Q',
#  '2PWGjXg4XBo',
#  'OyY_ls29DH8',
#  '-EmvmBuK-B8',
#  'oXq6srrSsJg',
#  'AQl8h7Aa75s',
#  'Z7L7UYwwy74',
#  'Ft-2LCqmdQY',
#  'FPLzzuwZyMo',
#  '-R8Jj-SpWZk',
#  'TeCEnOY3jGs',
#  'c6QGSzsnbPA',
#  'y196CIc3Y-I',
#  'bdzkbzscQm8',
#  'ptRkQUFDwmM',
#  'EwEpNBcJLZQ',
#  'wS4D-PRFZR0',
#  'msTcsxCxgmY',
#  'zlcbZxChTWQ',
#  'r95HUvHa4VM',
#  'QmO-jUp_lcI',
#  'kPGtqXjREGQ',
#  'bcaJWb3sGL4',
#  'BRE-chl-9EY',
#  'CokrncnNaLE',
#  'nLAVTQwXc48',
#  'k-S6dqqwEf4',
#  '6o7AJP6_4yw',
#  '9D-utcIogU4',
#  '2Q5NVkFmdB0',
#  'lbB7AhwaZy8',
#  'IfDqcWGzMF8',
#  '2Zi1a6jIwZ0',
#  'zUafO9dJYlY',
#  'OlHpTo2FUvQ',
#  'kIlKExSxCfQ',
#  'jukme9yHhtw',
#  'hLJw6O4p2Lk',
#  'zj0yud4wv74',
#  'NG8bQVMjv7E',
#  '04HWovMzkAk',
#  'zZQnYkoqJpY',
#  'FsM1IQ9d2pw',
#  '08LazrJEyvY',
#  'qj7Sg1BpipA',
#  'a-noreywVow',
#  'FeFKAl9KyMg',
#  '62FYNwd-8Jo',
#  'hHd4Cv3kkqE',
#  'PN_6cRkITSI',
#  'qJ5vHvSySdA',
#  'qZCanCxo0tI',
#  'rAUxj9FCgBg',
#  'leZa9BOuAOY',
#  '7XwzKmwueyw',
#  'Sfz3cP7J9tk',
#  '_8pWlMSMvh8',
#  'ZzJYnyd7cks',
#  'vZGvgru4TwE',
#  'hYDuXrBOJlM',
#  '8IJRzcPC9wg',
#  'XAhKKiAnIV0',
#  '9-7nJIUROdI',
#  'PQDiUKwXLVI',
#  'JYRkXhT1XEs',
#  '00AkRDtETzI',
#  'QfYOpBw_OW0',
#  'ycO-oWYvaQI',
#  'twmdoeEkCbU',
#  'QS-zUSu-nxA',
#  'la-yAfS0kOU',
#  'UUhOkIg6VGk',
#  'Vssg-nV4lvg',
#  '2tjkjMMv7IE',
#  'KkoZujArZFc',
#  'M0PEXquyhA4',
#  'QqTjZMtf-LU',
#  'IjLUlv1bHis',
#  'MgeAjcMXj8A',
#  'Gml1HT4y3_c',
#  'FzOc48bYcuc',
#  'S2EdR3my4m8',
#  'y8E7wRDPy5M',
#  'j72LtzBIv2A',
#  '3Ov6tuhZ2ro',
#  'NSjOplY8GCw',
#  'adNN6Dz30LU',
#  'C3ZGK6nePHk',
#  'qpp6AS7DcCs',
#  'kdTxN4E0vbo',
#  'cW7RpCYAOdI',
#  'rylfgRfyt_c',
#  'sk9L4EoT0gI',
#  'MgMNUne9j9c',
#  'FdXCyalOlOc',
#  'pNyl1R3Kabw',
#  'HTwGPZvDB4s',
#  'Sw7Jn8wKPnA',
#  'Tz14rC0XvHI',
#  'TKz5MuYPjnc',
#  '5iCr_KIb0vY',
#  'XG8q4eSWrVA',
#  'Nua4m-mYy-o',
#  'QJ8AW5pi2T4',
#  'JAqtLyT2UT0',
#  'S9GsI4iRb1Y',
#  '-nTz5EOjIwo',
#  'InwPx7vmUQg',
#  '2qxxd68fZng',
#  'b_83vbt0-bU',
#  'iNTfKTZ8Atc',
#  '5uae2DU9r8k',
#  'OSA6DC-nzOk',
#  'LOHKVp8hn7o',
#  'fICs5vjBuX0',
#  'QolV3meNgzc',
#  'b_1GoxLmDV4',
#  'zuUvQN8KXOk',
#  'AXH9Xm6Rbfc',
#  'nQBC00jIiHE',
#  '8XcYpmxDNqA',
#  '6-GqcQN9-IQ',
#  'zBaIXRvzaBQ',
#  'zHJ3h675nNk',
#  'xR8VcTFGi2g',
#  '2zhvaGNJiJ8',
#  'vclXSlAazUE',
#  '5zz6LlDVRl0',
#  'F_g4TzhWeSs',
#  'UubU3U2C8WM',
#  'Tcvxjp5pWlU',
#  '9u7tEl7iBkM',
#  'N6VanlUF6f4',
#  'ML5voEUtno8',
#  'DsUP-53h_hY',
#  '7BU2yTYKm0c',
#  '1Sl4stB0EPM',
#  '8QnsA_1pEd8',
#  'nZjt2hJCmJw',
#  'DUuTx2nbizM',
#  'AZSah-Ny5Is',
#  '96Pyuo96cPA',
#  '1s_5T5VgV_U',
#  'oTISukmgxaM',
#  'iU0yt2XkUCU',
#  'GT7gYqrNwyI',
#  'RaW9iw1Bq_s',
#  '8lT21wKoXyQ',
#  't_dnfZp1I3A',
#  'WTLl03D4TNA',
#  'sAPT6HTRcEs',
#  'j2PpRFS2NbI',
#  'Hs5JBjX51dc',
#  'fcqxmHD9gA0',
#  'TQvxWaQnrqI',
#  'IglMYrOnKbo',
#  'vJ6PNGlBq_Q',
#  'vfDoRCOamEg',
#  'rjWBuxqRstw',
#  'Loe-lMkJ8jU',
#  'lTNidJFIvXU',
#  'dKcsjcx0jNQ',
#  'qawipem0LwA',
#  'CzN1G048p-U',
#  'QhBufeT0l3g',
#  'KyD8VIK032o',
#  'tCJFh2h7ikI',
#  'zHbfZWZJTGc',
#  '2bJS-SxGbDM',
#  'FZMeuWh6eQM',
#  'NniisV69jYk',
#  'a77ShLMFFSI',
#  '6kAAXXHc4w8',
#  'lr0NTg3qyp0',
#  'PdazZC_xXKU',
#  'NwZkIbUkHSo',
#  'bu8KVE4PuFc',
#  '6nqMegdbxik',
#  '11-kGCZKcSY',
#  'ChiYv9Uk4-E',
#  'hynXuSYFwNE',
#  'V2HswnIM6r4',
#  'gNtaaaFKssU',
#  'TBtaeyKkykU',
#  'ulb_HuYdLzM',
#  '2LP2aMzw_wQ',
#  'WjiXbemBXkE',
#  'PXuExh1FEIo',
#  'vyYrvhbDhW4',
#  'YtX3SuHqKOs',
#  'KmvmLRznmzA',
#  'M8EqvIWhG5M',
#  'QAH-cCK1bS8',
#  'TucxiIB76bo',
#  'JDy95_eNPzM',
#  'EnKp15oQAwg',
#  'KYzEK7RszO4',
#  '0vHOVpdaB_M',
#  'fEUndCU6uLk',
#  'is1cg5yhdds',
#  'IbIR0RkdF_A',
#  'EOqmnHXL29M',
#  'P_jQ1B9UwpU',
#  'WWpRX7g_qvo',
#  'wIPqcR7QCwc',
#  '7zO6PtRQK50',
#  'Z1xA3_GwqMc',
#  '6ZFqfdnbrqE',
#  '8zJrjEV9n8o',
#  'ZB7uA5o0mS4',
#  'HZa1RwFHgwU',
#  'zFZ0yLRupfU',
#  'uwzQB0aufy8',
#  'RI7xCYBmDqQ',
#  '9_uTdCHp7vI',
#  '4C9GKyfUQkc',
#  'qs7CLpBLqEg',
#  'FLrcZvsvnVU',
#  'xUDldEkKBmU',
#  'd6vf4GQM_xE',
#  'NHsIY-MG7Xs',
#  '9kDpbZCK62Y',
#  'HUG0UhrtNBQ',
#  'YI4RRZ3ZM7g',
#  'uCNHpK1Xtd8',
#  'Vz2la3947I0',
#  '004dS4B3dHw',
#  'll_RovpJVow',
#  '6XpJW9HnPfE',
#  '8IFiamOXhZU',
#  'R1kfeURl9Rk',
#  'S7G-ruj22Uo',
#  'uMbCz1-M7j8',
#  'Htvq35lz1Yc',
#  'kSWJPWMZ0-c',
#  'yj7bfZKlIp8',
#  'tC5RalYWZ5Y',
#  'tM4TDL9Hj8U',
#  'SiDsDhsPLMI',
#  '-IhHHQI5yS8',
#  'I2k61JMk71M',
#  '8TveCTps_Xw',
#  'MgSc5ysT6L4',
#  'yig3QCfBTzc',
#  'uAmEXtio9Hk',
#  'fJcz5SBq3Ik',
#  'DPWEhl7gbu4',
#  'cl_YuKk9mzg',
#  'EP2ghkO0lSk',
#  '3CVBLADsQiY',
#  'VrbxO3d0flo',
#  'pDr6DDRHvUY',
#  'Zrtm3Rgk35A',
#  'HIW2JLa8Xmw',
#  'EMDzVZ8v-3M',
#  'I4u_1ST7Ezk',
#  'Eo3Dp0h5490',
#  ...]

# %% [markdown]
# Function to get video details

# %%
def get_video_details(youtube, video_ids):

    all_video_stats=[]
    for i in range (0,len(video_ids), 50):
        request = youtube.videos().list(
            part='snippet,statistics',
            id=','.join(video_ids[i:i+50])) #returns the vidoe details as a string and goes through 50 videos at a time
        response = request.execute() #returns json format file

        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                               Published_date= video['snippet']['publishedAt'],
                               Views=video['statistics']['viewCount'],
                               Likes=video['statistics']['likeCount'],
                              #dislikes are no longer availible on youtube API and are replaced with favoriteCount
                               #Comments=video['statistics']['commentCount'], #Note some channels disable comments
                               #description= video['snippet']['description']  # the description funtion works bun in the interest of the API Quaota it is commented out currently
                               )
            all_video_stats.append(video_stats)
                               
    return all_video_stats

# %%
Video_details = get_video_details(youtube, video_ids)
Video_details #outputs desired details from video
# Out:
# [{'Title': 'Bret and Eric Weinstein: Brothers in Fraudulence',
#   'Published_date': '2024-09-27T14:00:22Z',
#   'Views': '233190',
#   'Likes': '14424'},
#  {'Title': 'Ancient Mesopotamia Part 1: The Sumerians  (4100 – 1750 BCE)',
#   'Published_date': '2024-09-25T14:00:56Z',
#   'Views': '20788',
#   'Likes': '1574'},
#  {'Title': 'The Definitive Guide to Debunking Creationists Part 5: Philosophy/Theology',
#   'Published_date': '2024-09-23T14:01:01Z',
#   'Views': '53579',
#   'Likes': '4399'},
#  {'Title': 'Subphylum Myriapoda Part 2: Diversity of Centipedes and Millipedes',
#   'Published_date': '2024-09-20T14:00:03Z',
#   'Views': '19438',
#   'Likes': '420'},
#  {'Title': 'Homo sapiens: Last of the Hominins',
#   'Published_date': '2024-09-18T14:00:29Z',
#   'Views': '21924',
#   'Likes': '1705'},
#  {'Title': 'The Definitive Guide to Debunking Creationists Part 4: Genetics/Molecular Biology',
#   'Published_date': '2024-09-16T14:00:48Z',
#   'Views': '65520',
#   'Likes': '3741'},
#  {'Title': 'Structure and Bonding OCHEM Exam Question 5',
#   'Published_date': '2024-09-15T19:00:13Z',
#   'Views': '5275',
#   'Likes': '216'},
#  {'Title': 'Structure and Bonding OCHEM Exam Question 3',
#   'Published_date': '2024-09-15T14:00:39Z',
#   'Views': '6889',
#   'Likes': '292'},
#  {'Title': 'The Terrence Howard/Billy Carson Comedy Hour!',
#   'Published_date': '2024-09-14T14:00:18Z',
#   'Views': '217032',
#   'Likes': '12328'},
#  {'Title': 'Latin Nouns: Second Declension Part 4 (Neuter Nouns Part A)',
#   'Published_date': '2024-09-13T14:00:51Z',
#   'Views': '3000',
#   'Likes': '98'},
#  {'Title': 'Structure and Bonding OCHEM Exam Question 1',
#   'Published_date': '2024-09-12T17:00:34Z',
#   'Views': '5362',
#   'Likes': '335'},
#  {'Title': 'Would You Pass My Structure and Bonding Organic Chemistry Exam?',
#   'Published_date': '2024-09-12T14:00:53Z',
#   'Views': '8586',
#   'Likes': '270'},
#  {'Title': 'Contemporary Ethics Part 2: Metaethics and New Virtue Theories',
#   'Published_date': '2024-09-11T14:00:49Z',
#   'Views': '8850',
#   'Likes': '477'},
#  {'Title': 'The Definitive Guide to Debunking Creationists Part 3: Evolutionary Biology/Paleontology',
#   'Published_date': '2024-09-09T14:00:44Z',
#   'Views': '85371',
#   'Likes': '4620'},
#  {'Title': 'Subphylum Myriapoda Part 1: Form and Function',
#   'Published_date': '2024-09-06T14:00:04Z',
#   'Views': '30707',
#   'Likes': '442'},
#  {'Title': 'CD4+ T Cells',
#   'Published_date': '2024-09-04T14:00:54Z',
#   'Views': '5159',
#   'Likes': '242'},
#  {'Title': 'Can You Pass My OCHEM Assessment Exam?',
#   'Published_date': '2024-09-03T19:46:00Z',
#   'Views': '6359',
#   'Likes': '485'},
#  {'Title': 'Can You Pass My Organic Chemistry Assessment Exam?',
#   'Published_date': '2024-09-03T19:43:07Z',
#   'Views': '10700',
#   'Likes': '481'},
#  {'Title': 'The Definitive Guide to Debunking Creationists Part 2: Abiogenesis',
#   'Published_date': '2024-09-02T14:00:48Z',
#   'Views': '85231',
#   'Likes': '5061'},
#  {'Title': 'Latin Nouns: Second Declension Part 3 (Masculine Nouns Ending in -er)',
#   'Published_date': '2024-08-30T14:00:23Z',
#   'Views': '2883',
#   'Likes': '99'},
#  {'Title': 'Late Surviving Oddballs: Homo naledi and Homo floresiensis',
#   'Published_date': '2024-08-28T14:00:26Z',
#   'Views': '11897',
#   'Likes': '873'},
#  {'Title': 'The Definitive Guide to Debunking Creationists Part 1: Cosmology/Planetary Science',
#   'Published_date': '2024-08-26T14:00:49Z',
#   'Views': '178336',
#   'Likes': '10086'},
#  {'Title': 'Contemporary Ethics Part 1: The Birth of Metaethics',
#   'Published_date': '2024-08-23T14:00:25Z',
#   'Views': '8699',
#   'Likes': '490'},
#  {'Title': 'Subphylum Chelicerata Part 3: Diversity (Spiders, Mites, Ticks, and More)',
#   'Published_date': '2024-08-21T14:00:50Z',
#   'Views': '10349',
#   'Likes': '533'},
#  {'Title': 'AP Chemistry Long Answer Question 15 (Xenon)',
#   'Published_date': '2024-08-19T15:29:12Z',
#   'Views': '13',
#   'Likes': '2'},
#  {'Title': 'AP Chemistry Long Answer Question 14 (Sulfur)',
#   'Published_date': '2024-08-19T15:29:09Z',
#   'Views': '5',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Long Answer Question 13 (Polymers)',
#   'Published_date': '2024-08-19T15:29:06Z',
#   'Views': '2',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Long Answer Question 12 (Lattice Energy)',
#   'Published_date': '2024-08-19T15:29:02Z',
#   'Views': '3',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Long Answer Question 11 (Isomerization)',
#   'Published_date': '2024-08-19T15:28:59Z',
#   'Views': '4',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Long Answer Question 10 (Intermolecular Forces)',
#   'Published_date': '2024-08-19T15:28:56Z',
#   'Views': '7',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Long Answer Question 9 (Gravimetric Analysis)',
#   'Published_date': '2024-08-19T15:28:53Z',
#   'Views': '6',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Long Answer Question 8 (Gas Production)',
#   'Published_date': '2024-08-19T15:28:50Z',
#   'Views': '3',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Long Answer Question 7 (Gas Collection)',
#   'Published_date': '2024-08-19T15:28:47Z',
#   'Views': '2',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Long Answer Question 6 (Galvanic Cells)',
#   'Published_date': '2024-08-19T15:28:44Z',
#   'Views': '5',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Long Answer Question 5 (Fulminic Acid)',
#   'Published_date': '2024-08-19T15:28:41Z',
#   'Views': '5',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Long Answer Question 4 (Fluorine)',
#   'Published_date': '2024-08-19T15:28:37Z',
#   'Views': '5',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Long Answer Question 3 (Equilibria)',
#   'Published_date': '2024-08-19T15:28:34Z',
#   'Views': '3',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Long Answer Question 2 (Chlorine)',
#   'Published_date': '2024-08-19T15:28:31Z',
#   'Views': '4',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Long Answer Question 1 (Acids and Bases)',
#   'Published_date': '2024-08-19T15:28:28Z',
#   'Views': '6',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Short Answer Question 8 (Titration)',
#   'Published_date': '2024-08-19T15:28:24Z',
#   'Views': '5',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Short Answer Question 7 (Spectrophotometry)',
#   'Published_date': '2024-08-19T15:28:21Z',
#   'Views': '8',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Short Answer Question 6 (Photoelectron Spectra)',
#   'Published_date': '2024-08-19T15:28:17Z',
#   'Views': '9',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Short Answer Question 5 (Solubility Product Constant)',
#   'Published_date': '2024-08-19T15:28:14Z',
#   'Views': '6',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Short Answer Question 4 (Kinetics)',
#   'Published_date': '2024-08-19T15:28:10Z',
#   'Views': '6',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Short Answer Question 3 (Ionic Compounds)',
#   'Published_date': '2024-08-19T15:28:07Z',
#   'Views': '5',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Short Answer Question 2 (Enthalpy)',
#   'Published_date': '2024-08-19T15:28:03Z',
#   'Views': '6',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Short Answer Question 1 (Acid-Base Equilibria)',
#   'Published_date': '2024-08-19T15:27:59Z',
#   'Views': '9',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Unit 9 Multiple Choice Questions',
#   'Published_date': '2024-08-19T15:27:55Z',
#   'Views': '5',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Unit 8 Multiple Choice Questions',
#   'Published_date': '2024-08-19T15:27:51Z',
#   'Views': '6',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Unit 7 Multiple Choice Questions',
#   'Published_date': '2024-08-19T15:27:48Z',
#   'Views': '8',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Unit 6 Multiple Choice Questions',
#   'Published_date': '2024-08-19T15:27:44Z',
#   'Views': '4',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Unit 5 Multiple Choice Questions',
#   'Published_date': '2024-08-19T15:27:40Z',
#   'Views': '6',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Unit 4 Multiple Choice Questions',
#   'Published_date': '2024-08-19T15:27:37Z',
#   'Views': '14',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Unit 3 Multiple Choice Questions',
#   'Published_date': '2024-08-19T15:27:32Z',
#   'Views': '11',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Unit 2 Multiple Choice Questions',
#   'Published_date': '2024-08-19T15:26:06Z',
#   'Views': '14',
#   'Likes': '1'},
#  {'Title': 'AP Chemistry Unit 1 Multiple Choice Questions',
#   'Published_date': '2024-08-19T15:26:01Z',
#   'Views': '35',
#   'Likes': '3'},
#  {'Title': 'AP Chemistry Review: Unit 9 (Applications of Thermodynamics)',
#   'Published_date': '2024-08-19T15:25:44Z',
#   'Views': '43',
#   'Likes': '2'},
#  {'Title': 'AP Chemistry Review: Unit 8 (Acids and Bases)',
#   'Published_date': '2024-08-19T15:25:38Z',
#   'Views': '39',
#   'Likes': '3'},
#  {'Title': 'AP Chemistry Review: Unit 7 (Equilibrium)',
#   'Published_date': '2024-08-19T15:25:32Z',
#   'Views': '36',
#   'Likes': '2'},
#  {'Title': 'Introduction to World History: The Ancient World',
#   'Published_date': '2024-08-19T14:00:14Z',
#   'Views': '28444',
#   'Likes': '1816'},
#  {'Title': 'Latin Nouns: Second Declension Part 2 (Exceptions)',
#   'Published_date': '2024-08-16T14:00:30Z',
#   'Views': '3323',
#   'Likes': '139'},
#  {'Title': 'Neanderthals and Denisovans',
#   'Published_date': '2024-08-14T14:00:04Z',
#   'Views': '25659',
#   'Likes': '1905'},
#  {'Title': 'AP Chemistry Review: Unit 6 (Thermodynamics)',
#   'Published_date': '2024-08-12T14:00:25Z',
#   'Views': '5312',
#   'Likes': '266'},
#  {'Title': 'Discussion With Michael Beverly (Creationism, Science Communication, Education, and Society)',
#   'Published_date': '2024-08-10T14:00:27Z',
#   'Views': '28512',
#   'Likes': '1364'},
#  {'Title': 'More on Language and Meaning in Analytic Philosophy',
#   'Published_date': '2024-08-09T14:00:50Z',
#   'Views': '6049',
#   'Likes': '328'},
#  {'Title': 'Principles of Heterogeneous Catalysis',
#   'Published_date': '2024-08-07T14:00:40Z',
#   'Views': '5714',
#   'Likes': '289'},
#  {'Title': 'AP Chemistry Review: Unit 5 (Kinetics)',
#   'Published_date': '2024-08-05T14:00:13Z',
#   'Views': '5383',
#   'Likes': '252'},
#  {'Title': 'The Dangerous Rise of Anti-Intellectualism',
#   'Published_date': '2024-08-03T14:00:33Z',
#   'Views': '281060',
#   'Likes': '23909'},
#  {'Title': 'Subphylum Chelicerata Part 2: Reproduction, Adaptations, and Ecology',
#   'Published_date': '2024-08-02T14:00:47Z',
#   'Views': '6774',
#   'Likes': '392'},
#  {'Title': 'Middle Genus Homo (Muddle in the Middle)',
#   'Published_date': '2024-07-31T14:00:48Z',
#   'Views': '13801',
#   'Likes': '843'},
#  {'Title': 'AP Chemistry Review: Unit 4 (Chemical Reactions)',
#   'Published_date': '2024-07-29T14:00:32Z',
#   'Views': '6225',
#   'Likes': '288'},
#  {'Title': 'Latin Nouns: Second Declension Part 1 (Ending in -us)',
#   'Published_date': '2024-07-26T14:00:29Z',
#   'Views': '4238',
#   'Likes': '134'},
#  {'Title': 'Epistemology Part 1: Quine, Sellars, Gettier, and Putnam',
#   'Published_date': '2024-07-24T14:00:26Z',
#   'Views': '9796',
#   'Likes': '484'},
#  {'Title': 'AP Chemistry Review: Unit 3 (Intermolecular Forces and Properties)',
#   'Published_date': '2024-07-22T14:00:08Z',
#   'Views': '7445',
#   'Likes': '307'},
#  {'Title': 'Things I Was Supposed to Say on Piers Morgan',
#   'Published_date': '2024-07-20T14:00:07Z',
#   'Views': '550292',
#   'Likes': '23721'},
#  {'Title': 'Principles of Homogeneous Catalysis',
#   'Published_date': '2024-07-19T14:00:02Z',
#   'Views': '5706',
#   'Likes': '244'},
#  {'Title': 'Subphylum Chelicerata Part 1: Form and Function of the Arachnids',
#   'Published_date': '2024-07-17T14:00:25Z',
#   'Views': '14830',
#   'Likes': '679'},
#  {'Title': 'Update on Subboor Ahmad the Whiny Coward',
#   'Published_date': '2024-07-16T14:00:29Z',
#   'Views': '135094',
#   'Likes': '9846'},
#  {'Title': 'AP Chemistry Review: Unit 2 (Molecular and Ionic Compound Structure and Properties)',
#   'Published_date': '2024-07-15T14:00:46Z',
#   'Views': '9827',
#   'Likes': '327'},
#  {'Title': 'Homo erectus (Sensu Lato and Sensu Stricto)',
#   'Published_date': '2024-07-12T14:00:42Z',
#   'Views': '29633',
#   'Likes': '1783'},
#  {'Title': 'More Terrence Howard on Joe Rogan Insanity',
#   'Published_date': '2024-07-09T14:00:45Z',
#   'Views': '776199',
#   'Likes': '25462'},
#  {'Title': 'AP Chemistry Review: Unit 1 (Atomic Structure and Properties)',
#   'Published_date': '2024-07-08T14:00:36Z',
#   'Views': '41865',
#   'Likes': '1214'},
#  {'Title': 'Imperative Verbs in Latin (First and Second Conjugation)',
#   'Published_date': '2024-07-05T14:00:50Z',
#   'Views': '7727',
#   'Likes': '170'},
#  {'Title': 'Antigen Processing and Presentation by Major Histocompatibility Complexes',
#   'Published_date': '2024-07-03T14:00:30Z',
#   'Views': '11354',
#   'Likes': '403'},
#  {'Title': 'The Five Subphyla of Arthropoda (Including Trilobitomorpha)',
#   'Published_date': '2024-07-01T14:00:49Z',
#   'Views': '9310',
#   'Likes': '531'},
#  {'Title': 'Italian Culture: The History of Cannoli',
#   'Published_date': '2024-06-28T14:00:01Z',
#   'Views': '14635',
#   'Likes': '788'},
#  {'Title': 'Analytic Philosophy Part 3: Language and Meaning',
#   'Published_date': '2024-06-26T14:00:14Z',
#   'Views': '10055',
#   'Likes': '418'},
#  {'Title': 'Early Genus Homo: Homo habilis and Homo rudolfensis',
#   'Published_date': '2024-06-24T14:00:30Z',
#   'Views': '21690',
#   'Likes': '1390'},
#  {'Title': 'Heart Failure and the Beta-1 Adrenoceptor',
#   'Published_date': '2024-06-21T14:00:32Z',
#   'Views': '11863',
#   'Likes': '536'},
#  {'Title': 'Introduction to Phylum Arthropoda: 1.3 Million Species and Counting',
#   'Published_date': '2024-06-19T14:00:17Z',
#   'Views': '9996',
#   'Likes': '599'},
#  {'Title': 'Professor Dave Ruins Flat Earther Austin Witsit',
#   'Published_date': '2024-06-17T14:00:41Z',
#   'Views': '961059',
#   'Likes': '20416'},
#  {'Title': 'Billy Carson is Even Dumber Than Terrence Howard',
#   'Published_date': '2024-06-14T14:00:44Z',
#   'Views': '1478475',
#   'Likes': '41971'},
#  {'Title': 'Present Indicative Verbs (First and Second Conjugation)',
#   'Published_date': '2024-06-12T14:01:00Z',
#   'Views': '9850',
#   'Likes': '230'},
#  {'Title': 'Introduction to Transition Metal Catalysis',
#   'Published_date': '2024-06-10T14:00:00Z',
#   'Views': '8246',
#   'Likes': '356'},
#  {'Title': 'Discussion on Critical Faculty Podcast (Abiogenesis Research)',
#   'Published_date': '2024-06-07T14:00:32Z',
#   'Views': '22477',
#   'Likes': '864'},
#  {'Title': 'Paranthropus and Kenyanthropus',
#   'Published_date': '2024-06-05T14:00:18Z',
#   'Views': '23107',
#   'Likes': '885'},
#  {'Title': 'Analytic Philosophy Part 2: The Vienna Circle',
#   'Published_date': '2024-06-03T14:00:16Z',
#   'Views': '9218',
#   'Likes': '409'},
#  {'Title': 'T Cell Receptor Activation',
#   'Published_date': '2024-05-31T14:00:21Z',
#   'Views': '14453',
#   'Likes': '628'},
#  {'Title': 'Phylum Onychophora: Velvet Worms',
#   'Published_date': '2024-05-29T14:00:27Z',
#   'Views': '10347',
#   'Likes': '612'},
#  {'Title': 'More First Declension Nouns (Pluralia Tantum and Special Meanings)',
#   'Published_date': '2024-05-27T14:00:34Z',
#   'Views': '9980',
#   'Likes': '244'},
#  {'Title': 'Terrence Howard is Legitimately Insane',
#   'Published_date': '2024-05-24T14:00:38Z',
#   'Views': '2753570',
#   'Likes': '84015'},
#  {'Title': 'Genus Australopithecus',
#   'Published_date': '2024-05-22T14:00:18Z',
#   'Views': '31199',
#   'Likes': '1952'},
#  {'Title': 'Continental Philosophy Part 2: The Frankfurt School',
#   'Published_date': '2024-05-20T14:00:44Z',
#   'Views': '6839',
#   'Likes': '321'},
#  {'Title': 'Evolution Justice League Responds to Creationist Trolls',
#   'Published_date': '2024-05-17T14:00:06Z',
#   'Views': '73294',
#   'Likes': '3406'},
#  {'Title': 'Phylum Tardigrada: Water Bears and Moss Piglets',
#   'Published_date': '2024-05-15T14:00:14Z',
#   'Views': '21204',
#   'Likes': '1153'},
#  {'Title': 'Latin Nouns: First Declension',
#   'Published_date': '2024-05-13T14:00:24Z',
#   'Views': '7100',
#   'Likes': '253'},
#  {'Title': 'Tucker Carlson is a Creationist Tool',
#   'Published_date': '2024-05-10T14:00:31Z',
#   'Views': '327906',
#   'Likes': '21715'},
#  {'Title': 'The First Hominins',
#   'Published_date': '2024-05-08T14:00:21Z',
#   'Views': '55661',
#   'Likes': '3044'},
#  {'Title': 'Subboor Ahmad is a Whiny Toddler Coward',
#   'Published_date': '2024-05-07T14:00:18Z',
#   'Views': '144917',
#   'Likes': '10808'},
#  {'Title': 'Analytic Philosophy Part 1: Dewey, Russell, and Whitehead',
#   'Published_date': '2024-05-06T14:00:42Z',
#   'Views': '15879',
#   'Likes': '573'},
#  {'Title': 'T and B Cell Development: V(D)J Recombination',
#   'Published_date': '2024-05-03T14:00:02Z',
#   'Views': '13098',
#   'Likes': '400'},
#  {'Title': 'Phylum Nematomorpha: Parasitic Horsehair Worms',
#   'Published_date': '2024-05-01T14:00:27Z',
#   'Views': '8657',
#   'Likes': '419'},
#  {'Title': 'Introduction to Verbs in Latin',
#   'Published_date': '2024-04-29T14:00:23Z',
#   'Views': '11559',
#   'Likes': '274'},
#  {'Title': 'Eric Dubay Sucks at Life (200 Flat Earth “Proofs” Debunked)',
#   'Published_date': '2024-04-26T14:00:22Z',
#   'Views': '1439032',
#   'Likes': '39521'},
#  {'Title': 'Antiarrhythmic Drugs Part 2: Pharmacological Solutions',
#   'Published_date': '2024-04-24T14:00:37Z',
#   'Views': '6922',
#   'Likes': '246'},
#  {'Title': 'The Miocene Apes',
#   'Published_date': '2024-04-22T14:00:03Z',
#   'Views': '18135',
#   'Likes': '1102'},
#  {'Title': 'Continental Philosophy Part 1: Husserl, Bergson, Heidegger, and Jaspers',
#   'Published_date': '2024-04-19T14:00:22Z',
#   'Views': '6606',
#   'Likes': '283'},
#  {'Title': 'Phylum Nematoda Part 2: The Parasitic Nematodes',
#   'Published_date': '2024-04-17T14:00:05Z',
#   'Views': '9793',
#   'Likes': '473'},
#  {'Title': 'Word Order in Latin (Syntax)',
#   'Published_date': '2024-04-15T14:00:37Z',
#   'Views': '9862',
#   'Likes': '309'},
#  {'Title': 'The Anthropoids',
#   'Published_date': '2024-04-12T14:00:06Z',
#   'Views': '11624',
#   'Likes': '645'},
#  {'Title': 'Logic in Late Modern Philosophy',
#   'Published_date': '2024-04-10T14:00:24Z',
#   'Views': '11749',
#   'Likes': '527'},
#  {'Title': 'Introduction to Adaptive Immunity',
#   'Published_date': '2024-04-08T14:00:22Z',
#   'Views': '10658',
#   'Likes': '466'},
#  {'Title': 'Reacting to Muslim Creationists (Subboor Ahmad and Muslim Lantern Debunked)',
#   'Published_date': '2024-04-05T14:02:34Z',
#   'Views': '454528',
#   'Likes': '12883'},
#  {'Title': 'Phylum Nematoda Part 1: Introduction to the Roundworms',
#   'Published_date': '2024-04-03T14:00:26Z',
#   'Views': '23195',
#   'Likes': '612'},
#  {'Title': 'The Latin Noun System',
#   'Published_date': '2024-04-01T14:00:13Z',
#   'Views': '5942',
#   'Likes': '294'},
#  {'Title': 'Antiarrythmic Drugs Part 1: The Physiology of Heart Rhythm',
#   'Published_date': '2024-03-29T14:00:49Z',
#   'Views': '7524',
#   'Likes': '361'},
#  {'Title': 'The Adapids and the Omomyids',
#   'Published_date': '2024-03-27T14:00:36Z',
#   'Views': '9614',
#   'Likes': '544'},
#  {'Title': 'Logic in Early Modern Philosophy',
#   'Published_date': '2024-03-25T14:00:16Z',
#   'Views': '21846',
#   'Likes': '906'},
#  {'Title': 'Exposing Discovery Institute Part 9: Douglas Axe',
#   'Published_date': '2024-03-22T14:00:43Z',
#   'Views': '102353',
#   'Likes': '5673'},
#  {'Title': 'Phylum Priapulida: The Penis Worms',
#   'Published_date': '2024-03-20T14:00:21Z',
#   'Views': '14279',
#   'Likes': '796'},
#  {'Title': 'Parts of Speech in Latin',
#   'Published_date': '2024-03-18T14:00:40Z',
#   'Views': '9943',
#   'Likes': '331'},
#  {'Title': 'James Tour Gets EXPOSED by His Own Colleagues',
#   'Published_date': '2024-03-15T14:00:18Z',
#   'Views': '206322',
#   'Likes': '10103'},
#  {'Title': 'The Origin of Primates',
#   'Published_date': '2024-03-13T14:00:21Z',
#   'Views': '28760',
#   'Likes': '1785'},
#  {'Title': 'Late Modern Philosophy Part 2: The Roots of Analytic Philosophy',
#   'Published_date': '2024-03-11T14:00:38Z',
#   'Views': '6274',
#   'Likes': '370'},
#  {'Title': 'Innate Lymphoid Cells',
#   'Published_date': '2024-03-08T15:00:46Z',
#   'Views': '12874',
#   'Likes': '329'},
#  {'Title': 'Phylum Kinorhyncha: Microscopic Mud Dragons',
#   'Published_date': '2024-03-06T15:00:31Z',
#   'Views': '6492',
#   'Likes': '361'},
#  {'Title': 'Latin and English: Cognates',
#   'Published_date': '2024-03-04T15:00:35Z',
#   'Views': '9739',
#   'Likes': '335'},
#  {'Title': 'Stadler and Tour: The Newest Hit Comedy Duo!',
#   'Published_date': '2024-03-01T15:00:10Z',
#   'Views': '226906',
#   'Likes': '7772'},
#  {'Title': 'Vasodilators (Treating Hypertension)',
#   'Published_date': '2024-02-28T15:00:20Z',
#   'Views': '11243',
#   'Likes': '467'},
#  {'Title': 'Human Osteology (Axial and Appendicular Skeleton)',
#   'Published_date': '2024-02-26T15:00:05Z',
#   'Views': '21525',
#   'Likes': '720'},
#  {'Title': 'Late Modern Philosophy Part 1: The Roots of Continental Philosophy',
#   'Published_date': '2024-02-23T15:00:50Z',
#   'Views': '9192',
#   'Likes': '469'},
#  {'Title': 'Phylum Loricifera: Microscopic Armor-Bearers',
#   'Published_date': '2024-02-21T15:00:27Z',
#   'Views': '5993',
#   'Likes': '323'},
#  {'Title': 'Conservation Ecology: Threats to Biodiversity',
#   'Published_date': '2024-02-19T15:00:09Z',
#   'Views': '13345',
#   'Likes': '498'},
#  {'Title': 'Latin Phonetics Part 2: Consonants',
#   'Published_date': '2024-02-16T15:00:00Z',
#   'Views': '13741',
#   'Likes': '395'},
#  {'Title': 'Vasoconstrictors (Treating Hypotension)',
#   'Published_date': '2024-02-14T15:00:12Z',
#   'Views': '7730',
#   'Likes': '324'},
#  {'Title': 'Mechanisms of Evolution in the Context of Anthropology',
#   'Published_date': '2024-02-12T15:00:30Z',
#   'Views': '12796',
#   'Likes': '793'},
#  {'Title': 'All Aboard the James Tour Damage Control Train!',
#   'Published_date': '2024-02-09T15:00:41Z',
#   'Views': '254870',
#   'Likes': '9630'},
#  {'Title': 'Introduction to Ecdysozoa: Invertebrates With Cuticles',
#   'Published_date': '2024-02-07T15:00:14Z',
#   'Views': '8176',
#   'Likes': '389'},
#  {'Title': 'Community Ecology and Landscape Ecology',
#   'Published_date': '2024-02-05T15:00:02Z',
#   'Views': '8782',
#   'Likes': '448'},
#  {'Title': 'Latin Phonetics Part 1: Vowels',
#   'Published_date': '2024-02-02T15:00:17Z',
#   'Views': '14556',
#   'Likes': '749'},
#  {'Title': 'Cardiovascular Volume-Regulating Drugs',
#   'Published_date': '2024-01-31T15:00:14Z',
#   'Views': '7120',
#   'Likes': '322'},
#  {'Title': 'How Genetics Interacts with Biological Anthropology',
#   'Published_date': '2024-01-29T15:00:20Z',
#   'Views': '18490',
#   'Likes': '836'},
#  {'Title': "Science Isn't Dogma, You're Just Stupid (Response to Formscapes)",
#   'Published_date': '2024-01-26T15:00:50Z',
#   'Views': '669204',
#   'Likes': '27666'},
#  {'Title': 'Political Philosophy Part 2: Wollstonecraft, Bentham, Mill, and Marx',
#   'Published_date': '2024-01-24T15:00:49Z',
#   'Views': '10359',
#   'Likes': '552'},
#  {'Title': 'Population Ecology (Life Tables, Age Structure, Population Growth)',
#   'Published_date': '2024-01-22T15:00:37Z',
#   'Views': '22610',
#   'Likes': '679'},
#  {'Title': 'Introduction to the Latin Language',
#   'Published_date': '2024-01-19T15:00:25Z',
#   'Views': '41176',
#   'Likes': '1553'},
#  {'Title': 'Angiotensin-Converting Enzyme Inhibitors (ACE Inhibitors)',
#   'Published_date': '2024-01-17T15:00:04Z',
#   'Views': '25308',
#   'Likes': '654'},
#  {'Title': 'History of Biological Anthropology (Up to Genetics)',
#   'Published_date': '2024-01-15T15:00:10Z',
#   'Views': '25249',
#   'Likes': '1206'},
#  {'Title': 'Political Philosophy Part 1: Machiavelli, Rousseau, and Smith',
#   'Published_date': '2024-01-12T15:00:06Z',
#   'Views': '10588',
#   'Likes': '536'},
#  {'Title': 'Mitsunobu Reaction',
#   'Published_date': '2024-01-10T15:00:26Z',
#   'Views': '10625',
#   'Likes': '283'},
#  {'Title': 'Behavioral Ecology (Foraging, Parasitism, Mutualism, Mate Choice, and Social Groups)',
#   'Published_date': '2024-01-08T15:00:31Z',
#   'Views': '9144',
#   'Likes': '485'},
#  {'Title': 'Phylum Phoronida: The Horseshoe Worms (And a Summary of Lophophorata)',
#   'Published_date': '2024-01-04T15:00:15Z',
#   'Views': '6291',
#   'Likes': '279'},
#  {'Title': 'Introduction to Anthropology',
#   'Published_date': '2024-01-02T15:00:21Z',
#   'Views': '73206',
#   'Likes': '2246'},
#  {'Title': 'Idealism Part 2: Fichte, Schiller, Hegel, and Schelling',
#   'Published_date': '2023-12-28T15:00:09Z',
#   'Views': '11480',
#   'Likes': '373'},
#  {'Title': 'Food Webs and Trophic Cascades',
#   'Published_date': '2023-12-26T15:00:02Z',
#   'Views': '12958',
#   'Likes': '428'},
#  {'Title': 'Shapiro Reaction',
#   'Published_date': '2023-12-22T15:00:21Z',
#   'Views': '13209',
#   'Likes': '415'},
#  {'Title': 'Natural Killer Cells: The Tumor Killers',
#   'Published_date': '2023-12-20T15:00:29Z',
#   'Views': '20418',
#   'Likes': '760'},
#  {'Title': 'Phylum Brachiopoda: The Lamp Shells',
#   'Published_date': '2023-12-18T15:00:43Z',
#   'Views': '8193',
#   'Likes': '435'},
#  {'Title': 'James Tour Goes to Harvard (And Humiliates Himself)',
#   'Published_date': '2023-12-15T15:00:07Z',
#   'Views': '555629',
#   'Likes': '18557'},
#  {'Title': 'Energy Flow and Nutrient Cycling in Autotrophs and Heterotrophs',
#   'Published_date': '2023-12-13T15:00:13Z',
#   'Views': '10766',
#   'Likes': '421'},
#  {'Title': 'Idealism Part 1: Berkeley and Kant',
#   'Published_date': '2023-12-11T15:00:10Z',
#   'Views': '13786',
#   'Likes': '678'},
#  {'Title': 'Look Inside Your Stomach!',
#   'Published_date': '2023-12-09T15:00:33Z',
#   'Views': '34613',
#   'Likes': '2078'},
#  {'Title': 'Announcement: New T-Shirt Designs!',
#   'Published_date': '2023-12-09T15:00:19Z',
#   'Views': '4478',
#   'Likes': '250'},
#  {'Title': 'Exposing Discovery Institute Part 8: Jonathan Wells',
#   'Published_date': '2023-12-08T15:00:19Z',
#   'Views': '157338',
#   'Likes': '6354'},
#  {'Title': 'Phylum Entoprocta: The Goblet Worms',
#   'Published_date': '2023-12-06T15:00:07Z',
#   'Views': '5444',
#   'Likes': '252'},
#  {'Title': 'Stetter Reaction',
#   'Published_date': '2023-12-04T15:00:19Z',
#   'Views': '5940',
#   'Likes': '229'},
#  {'Title': 'Check Out This Trappist Exoplanet!',
#   'Published_date': '2023-12-02T15:00:24Z',
#   'Views': '16835',
#   'Likes': '922'},
#  {'Title': 'Terrestrial Biomes Part 2: Forests and Tundra',
#   'Published_date': '2023-12-01T15:00:31Z',
#   'Views': '9978',
#   'Likes': '289'},
#  {'Title': 'Empiricism Part 2: Locke, Hume, and Voltaire',
#   'Published_date': '2023-11-29T15:00:06Z',
#   'Views': '8139',
#   'Likes': '398'},
#  {'Title': 'Basophils and Eosinophils',
#   'Published_date': '2023-11-27T15:00:46Z',
#   'Views': '12798',
#   'Likes': '458'},
#  {'Title': 'Examining the Large Intestine',
#   'Published_date': '2023-11-25T15:00:50Z',
#   'Views': '29862',
#   'Likes': '1314'},
#  {'Title': 'Education Economics (Options and Cost for Post-Secondary Programs)',
#   'Published_date': '2023-11-24T15:00:41Z',
#   'Views': '6465',
#   'Likes': '255'},
#  {'Title': 'Phylum Bryozoa: The Moss Animals',
#   'Published_date': '2023-11-22T15:00:26Z',
#   'Views': '9606',
#   'Likes': '445'},
#  {'Title': 'Horner-Wadsworth-Emmons Reaction',
#   'Published_date': '2023-11-20T15:00:04Z',
#   'Views': '7839',
#   'Likes': '236'},
#  {'Title': 'Exoplanets and Magnetic Fields',
#   'Published_date': '2023-11-18T15:00:49Z',
#   'Views': '13016',
#   'Likes': '684'},
#  {'Title': 'Terrestrial Biomes Part 1: Rainforest, Desert, Grassland, and Shrubland',
#   'Published_date': '2023-11-17T15:00:06Z',
#   'Views': '15570',
#   'Likes': '480'},
#  {'Title': 'Empiricism Part 1: Da Vinci, Bacon, and Hobbes',
#   'Published_date': '2023-11-15T15:00:13Z',
#   'Views': '10773',
#   'Likes': '550'},
#  {'Title': 'Volcanoes: Formation, Types, and Activity',
#   'Published_date': '2023-11-13T15:00:44Z',
#   'Views': '17515',
#   'Likes': '736'},
#  {'Title': 'How Do We Study Quasars?',
#   'Published_date': '2023-11-11T15:00:12Z',
#   'Views': '12863',
#   'Likes': '687'},
#  {'Title': 'Mast Cells: Strategic Granulocytes',
#   'Published_date': '2023-11-10T15:00:03Z',
#   'Views': '11048',
#   'Likes': '369'},
#  {'Title': 'Phylum Nemertea: The Ribbon Worms',
#   'Published_date': '2023-11-08T15:00:31Z',
#   'Views': '11828',
#   'Likes': '365'},
#  {'Title': 'Types of Insurance (Health, Life, Property, and Auto)',
#   'Published_date': '2023-11-06T15:00:19Z',
#   'Views': '12957',
#   'Likes': '449'},
#  {'Title': 'What Do Geologists Do?',
#   'Published_date': '2023-11-04T14:00:16Z',
#   'Views': '18479',
#   'Likes': '871'},
#  {'Title': 'Animal Ecology (Fauna) Part 2: Water Balance and Photoperiods',
#   'Published_date': '2023-11-03T14:00:30Z',
#   'Views': '5293',
#   'Likes': '273'},
#  {'Title': 'Julia Reaction',
#   'Published_date': '2023-11-01T14:00:49Z',
#   'Views': '7702',
#   'Likes': '268'},
#  {'Title': 'Methods of Dating the Earth Part 2: Absolute Dating (Radiometric Dating)',
#   'Published_date': '2023-10-30T14:00:12Z',
#   'Views': '32212',
#   'Likes': '1121'},
#  {'Title': 'Visualizing the Digestive System',
#   'Published_date': '2023-10-28T14:00:01Z',
#   'Views': '18934',
#   'Likes': '966'},
#  {'Title': 'Introduction to Modern Philosophy: The Emergence of Rationalism',
#   'Published_date': '2023-10-27T14:00:13Z',
#   'Views': '24884',
#   'Likes': '980'},
#  {'Title': 'How to Get and Use Credit Cards',
#   'Published_date': '2023-10-25T14:00:12Z',
#   'Views': '22789',
#   'Likes': '1147'},
#  {'Title': 'Phylum Annelida Part 3: Oligochaeta and Hirudinea (Segmented Terrestrial/Aquatic Worms and Leeches)',
#   'Published_date': '2023-10-23T14:00:39Z',
#   'Views': '13174',
#   'Likes': '456'},
#  {'Title': 'How Big is the Universe?',
#   'Published_date': '2023-10-21T14:00:42Z',
#   'Views': '35618',
#   'Likes': '1456'},
#  {'Title': 'Animal Ecology (Fauna) Part 1: Food Acquisition and Body Temperature',
#   'Published_date': '2023-10-20T14:00:10Z',
#   'Views': '7536',
#   'Likes': '346'},
#  {'Title': 'Neutrophils: First Line of Defense',
#   'Published_date': '2023-10-18T14:00:10Z',
#   'Views': '26495',
#   'Likes': '690'},
#  {'Title': 'Methods of Dating the Earth Part 1: Relative Dating',
#   'Published_date': '2023-10-16T14:00:09Z',
#   'Views': '48715',
#   'Likes': '1540'},
#  {'Title': 'Travel Through the Aortic Valve of the Human Heart!',
#   'Published_date': '2023-10-14T14:00:09Z',
#   'Views': '29939',
#   'Likes': '1612'},
#  {'Title': 'An Overview of Medieval Logic',
#   'Published_date': '2023-10-13T14:00:30Z',
#   'Views': '24723',
#   'Likes': '1234'},
#  {'Title': 'Plant Ecology (Flora)',
#   'Published_date': '2023-10-11T14:00:33Z',
#   'Views': '7690',
#   'Likes': '383'},
#  {'Title': 'James Tour Has Hit Rock Bottom',
#   'Published_date': '2023-10-09T14:00:12Z',
#   'Views': '344476',
#   'Likes': '12602'},
#  {'Title': 'How Do We Find Binary Star Systems?',
#   'Published_date': '2023-10-07T14:00:36Z',
#   'Views': '12318',
#   'Likes': '704'},
#  {'Title': 'Phylum Annelida Part 2: Polychaeta (Segmented Marine Worms)',
#   'Published_date': '2023-10-06T14:00:32Z',
#   'Views': '18632',
#   'Likes': '562'},
#  {'Title': 'Weathering Environments Part 3: Glacial Processes',
#   'Published_date': '2023-10-04T14:00:39Z',
#   'Views': '9982',
#   'Likes': '365'},
#  {'Title': 'Late Medieval Philosophy: Abelard, Avicenna, Aquinas, et al.',
#   'Published_date': '2023-10-02T14:00:42Z',
#   'Views': '16239',
#   'Likes': '710'},
#  {'Title': 'Exposing Discovery Institute Part 7: John G. West',
#   'Published_date': '2023-09-29T14:00:23Z',
#   'Views': '144225',
#   'Likes': '7476'},
#  {'Title': 'Dendritic Cells: The Regulators',
#   'Published_date': '2023-09-27T14:00:31Z',
#   'Views': '29697',
#   'Likes': '729'},
#  {'Title': 'Why Was Socrates Sentenced to Death?',
#   'Published_date': '2023-09-26T14:00:31Z',
#   'Views': '20696',
#   'Likes': '1017'},
#  {'Title': 'The Terrestrial Environment',
#   'Published_date': '2023-09-25T14:00:34Z',
#   'Views': '11675',
#   'Likes': '366'},
#  {'Title': 'Quasar Discovered Without Host Galaxy!',
#   'Published_date': '2023-09-23T14:00:03Z',
#   'Views': '12527',
#   'Likes': '715'},
#  {'Title': 'Phylum Annelida Part 1: General Characteristics',
#   'Published_date': '2023-09-22T14:00:45Z',
#   'Views': '39936',
#   'Likes': '918'},
#  {'Title': 'Weathering Environments Part 2: Aeolian Processes',
#   'Published_date': '2023-09-20T14:00:44Z',
#   'Views': '9278',
#   'Likes': '359'},
#  {'Title': 'Could Life Exist in the Proxima Centauri System?',
#   'Published_date': '2023-09-19T14:00:23Z',
#   'Views': '14504',
#   'Likes': '662'},
#  {'Title': 'The Basics of Investing (Stocks, Bonds, Mutual Funds, and Types of Interest)',
#   'Published_date': '2023-09-18T14:00:37Z',
#   'Views': '148121',
#   'Likes': '3940'},
#  {'Title': 'Stellar Feeding Frenzy!',
#   'Published_date': '2023-09-16T14:00:27Z',
#   'Views': '7823',
#   'Likes': '407'},
#  {'Title': 'Early Medieval Philosophy: Augustine of Hippo and Boethius',
#   'Published_date': '2023-09-15T14:00:10Z',
#   'Views': '23969',
#   'Likes': '842'},
#  {'Title': 'Macrophages: The Destroyers',
#   'Published_date': '2023-09-13T14:00:37Z',
#   'Views': '45601',
#   'Likes': '1229'},
#  {'Title': 'Look Inside the Human Stomach!',
#   'Published_date': '2023-09-12T14:00:02Z',
#   'Views': '27799',
#   'Likes': '1080'},
#  {'Title': 'The Aquatic Environment: Marine and Freshwater',
#   'Published_date': '2023-09-11T14:00:32Z',
#   'Views': '24901',
#   'Likes': '660'},
#  {'Title': 'The Worlds of the Trappist System',
#   'Published_date': '2023-09-09T14:00:25Z',
#   'Views': '11306',
#   'Likes': '567'},
#  {'Title': 'Phylum Mollusca Part 5: The Lesser Known Classes',
#   'Published_date': '2023-09-08T14:00:39Z',
#   'Views': '10785',
#   'Likes': '413'},
#  {'Title': 'Exposing Discovery Institute Part 6: Jonathan McLatchie',
#   'Published_date': '2023-09-06T14:00:39Z',
#   'Views': '214000',
#   'Likes': '9283'},
#  {'Title': 'Forest Ecosystems: Energy Flow and Nutrient Recycling',
#   'Published_date': '2023-09-05T14:00:41Z',
#   'Views': '6780',
#   'Likes': '289'},
#  {'Title': 'The Golden Era of Pharmaceutical Research',
#   'Published_date': '2023-09-04T14:00:31Z',
#   'Views': '17670',
#   'Likes': '816'},
#  {'Title': 'Quasars and Glowing Gas Halos',
#   'Published_date': '2023-09-02T14:00:17Z',
#   'Views': '7847',
#   'Likes': '496'},
#  {'Title': 'The Functions of Modern Banks',
#   'Published_date': '2023-09-01T14:00:48Z',
#   'Views': '18986',
#   'Likes': '643'},
#  {'Title': 'Weathering Environments Part 1: Fluvial Processes',
#   'Published_date': '2023-08-30T14:00:09Z',
#   'Views': '19032',
#   'Likes': '608'},
#  {'Title': 'Geology and Planetary Science',
#   'Published_date': '2023-08-29T14:00:36Z',
#   'Views': '9618',
#   'Likes': '447'},
#  {'Title': 'Exploring New Frontiers Beyond Our Solar System',
#   'Published_date': '2023-08-26T14:00:21Z',
#   'Views': '7114',
#   'Likes': '426'},
#  {'Title': 'The Evolution of Life in the Context of Ecology',
#   'Published_date': '2023-08-24T14:00:23Z',
#   'Views': '13416',
#   'Likes': '721'},
#  {'Title': 'Journey through the Pulmonary Trunk',
#   'Published_date': '2023-08-23T14:00:26Z',
#   'Views': '15840',
#   'Likes': '615'},
#  {'Title': 'Introduction to Personal Economics: The Purpose of Money',
#   'Published_date': '2023-08-21T14:00:14Z',
#   'Views': '11497',
#   'Likes': '551'},
#  {'Title': 'Amazing Quasars!',
#   'Published_date': '2023-08-19T14:30:11Z',
#   'Views': '10482',
#   'Likes': '563'},
#  {'Title': 'Phylum Mollusca Part 4: Class Cephalopoda (Squids, Nautiluses, Cuttlefish, and Octopuses)',
#   'Published_date': '2023-08-17T14:30:24Z',
#   'Views': '19297',
#   'Likes': '736'},
#  {'Title': "Plato's Allegory of the Cave",
#   'Published_date': '2023-08-16T14:30:00Z',
#   'Views': '13606',
#   'Likes': '637'},
#  {'Title': 'Chemical Weathering Processes',
#   'Published_date': '2023-08-14T14:30:07Z',
#   'Views': '39141',
#   'Likes': '785'},
#  {'Title': 'Unlocking the Secrets of the Ecosystem',
#   'Published_date': '2023-08-12T14:30:20Z',
#   'Views': '8162',
#   'Likes': '402'},
#  {'Title': 'Clinical Psychology Part 2: Present-Day Therapy',
#   'Published_date': '2023-08-10T14:30:21Z',
#   'Views': '25131',
#   'Likes': '822'},
#  {'Title': 'Beyond Our Solar System: The Search for Habitable Worlds',
#   'Published_date': '2023-08-09T14:30:11Z',
#   'Views': '12163',
#   'Likes': '537'},
#  {'Title': 'Discussion on Critical Faculty Podcast (James Tour Debate)',
#   'Published_date': '2023-08-07T14:30:00Z',
#   'Views': '19423',
#   'Likes': '872'},
#  {'Title': "Unlocking Earth's Hidden Treasures!",
#   'Published_date': '2023-08-05T14:30:21Z',
#   'Views': '8476',
#   'Likes': '443'},
#  {'Title': 'Understanding Climate Part 2: Volcanoes, Oceans, and Internal Variability',
#   'Published_date': '2023-08-03T14:30:00Z',
#   'Views': '13273',
#   'Likes': '651'},
#  {'Title': 'Journey Inside the Heart!',
#   'Published_date': '2023-08-02T14:30:00Z',
#   'Views': '11716',
#   'Likes': '550'},
#  {'Title': 'Physical Weathering Processes',
#   'Published_date': '2023-07-31T14:30:13Z',
#   'Views': '48542',
#   'Likes': '916'},
#  {'Title': 'Looking at Space Stuff at Mt. Wilson Observatory! #shorts',
#   'Published_date': '2023-07-29T14:30:11Z',
#   'Views': '9447',
#   'Likes': '601'},
#  {'Title': 'Phylum Mollusca Part 3: Class Bivalvia (Clams, Oysters, Mussels, etc.)',
#   'Published_date': '2023-07-27T14:30:30Z',
#   'Views': '20493',
#   'Likes': '667'},
#  {'Title': 'Exposing Discovery Institute Part 5: Günter Bechly Again (Because He’s So Stupid)',
#   'Published_date': '2023-07-24T14:30:03Z',
#   'Views': '188007',
#   'Likes': '5949'},
#  {'Title': 'Exchange Rates and Trade',
#   'Published_date': '2023-07-20T14:30:06Z',
#   'Views': '54756',
#   'Likes': '1350'},
#  {'Title': 'Understanding Climate Part 1: Orbital Variations and the Sun',
#   'Published_date': '2023-07-17T14:30:11Z',
#   'Views': '35854',
#   'Likes': '1585'},
#  {'Title': 'Discussion on MythVision Podcast (James Tour Debate - Featuring Aron Ra)',
#   'Published_date': '2023-07-13T14:30:14Z',
#   'Views': '113085',
#   'Likes': '3007'},
#  {'Title': 'Flat Earth Priest Brainwashing 101 #shorts',
#   'Published_date': '2023-07-12T14:30:03Z',
#   'Views': '60837',
#   'Likes': '3621'},
#  {'Title': 'The Rock Cycle',
#   'Published_date': '2023-07-10T14:30:07Z',
#   'Views': '216509',
#   'Likes': '2997'},
#  {'Title': 'Phylum Mollusca Part 2: Class Gastropoda (Slugs and Snails)',
#   'Published_date': '2023-07-06T14:30:13Z',
#   'Views': '25563',
#   'Likes': '759'},
#  {'Title': 'These Facts About Laughter Are Insane 🤯 #shorts',
#   'Published_date': '2023-07-05T15:56:42Z',
#   'Views': '18795',
#   'Likes': '1086'},
#  {'Title': 'Logic in Late Ancient Philosophy',
#   'Published_date': '2023-07-03T14:30:20Z',
#   'Views': '16201',
#   'Likes': '743'},
#  {'Title': 'Superstition Is Deeper Than You Think 😱 #shorts',
#   'Published_date': '2023-07-01T14:46:34Z',
#   'Views': '18951',
#   'Likes': '1162'},
#  {'Title': 'Discussion on Bridge the Divide Podcast (James Tour Debate)',
#   'Published_date': '2023-06-29T14:30:09Z',
#   'Views': '37851',
#   'Likes': '1764'},
#  {'Title': 'Free Trade vs. Protectionism',
#   'Published_date': '2023-06-26T14:30:18Z',
#   'Views': '72968',
#   'Likes': '1883'},
#  {'Title': 'Types of Metamorphism: Low P/T, Medium P/T, and High P/T',
#   'Published_date': '2023-06-22T14:30:04Z',
#   'Views': '21354',
#   'Likes': '660'},
#  {'Title': 'Hellenistic and Roman Philosophy',
#   'Published_date': '2023-06-19T14:30:15Z',
#   'Views': '24484',
#   'Likes': '1039'},
#  {'Title': 'Response to “Capturing Christianity” James Tour Debate Analysis',
#   'Published_date': '2023-06-15T14:30:03Z',
#   'Views': '148926',
#   'Likes': '6634'},
#  {'Title': 'Scales of Ecology Part 3: Ecosystems',
#   'Published_date': '2023-06-12T14:30:11Z',
#   'Views': '12414',
#   'Likes': '442'},
#  {'Title': 'Fact-Checking James Tour’s Embarrassing Debate Performance',
#   'Published_date': '2023-06-06T14:30:15Z',
#   'Views': '625735',
#   'Likes': '16647'},
#  {'Title': 'Phylum Mollusca Part 1: General Introduction',
#   'Published_date': '2023-06-05T14:30:16Z',
#   'Views': '51758',
#   'Likes': '1328'},
#  {'Title': 'Origin of Metamorphic Rocks',
#   'Published_date': '2023-06-01T14:30:00Z',
#   'Views': '40600',
#   'Likes': '926'},
#  {'Title': 'Clinical Psychology Part 1: Sigmund Freud and Psychoanalysis',
#   'Published_date': '2023-05-29T14:30:10Z',
#   'Views': '147578',
#   'Likes': '3771'},
#  {'Title': 'Dave Farina vs. James Tour Debate (Are We Clueless About the Origin of Life?)',
#   'Published_date': '2023-05-23T14:14:40Z',
#   'Views': '745125',
#   'Likes': '21676'},
#  {'Title': 'Aristotelian Logic',
#   'Published_date': '2023-05-22T14:30:30Z',
#   'Views': '30898',
#   'Likes': '1289'},
#  {'Title': 'Scales of Ecology Part 2: Communities',
#   'Published_date': '2023-05-18T14:30:12Z',
#   'Views': '14064',
#   'Likes': '390'},
#  {'Title': 'Classification of Sedimentary Rocks Part 3: Chemogenic Rocks',
#   'Published_date': '2023-05-15T14:30:15Z',
#   'Views': '10073',
#   'Likes': '366'},
#  {'Title': 'Gross Domestic Product (GDP)',
#   'Published_date': '2023-05-11T14:30:13Z',
#   'Views': '145027',
#   'Likes': '3533'},
#  {'Title': 'Aristotle: The First Scientist',
#   'Published_date': '2023-05-08T14:30:15Z',
#   'Views': '45018',
#   'Likes': '1570'},
#  {'Title': 'Scales of Ecology Part 1: Organisms and Populations',
#   'Published_date': '2023-05-05T14:30:19Z',
#   'Views': '23621',
#   'Likes': '632'},
#  {'Title': 'Phylum Rotifera Part 3: Subclade Acanthocephala (Parasitic Spiny-Headed Worms)',
#   'Published_date': '2023-05-03T14:30:25Z',
#   'Views': '7747',
#   'Likes': '256'},
#  {'Title': 'Classification of Sedimentary Rocks Part 2: Biogenic Rocks',
#   'Published_date': '2023-05-01T14:30:09Z',
#   'Views': '11987',
#   'Likes': '416'},
#  {'Title': 'Exchanging 10 Questions With Mr. Beat',
#   'Published_date': '2023-04-28T14:30:00Z',
#   'Views': '24980',
#   'Likes': '865'},
#  {'Title': 'The Roots of Logic in the Ancient World',
#   'Published_date': '2023-04-26T14:30:16Z',
#   'Views': '28471',
#   'Likes': '1175'},
#  {'Title': 'Introduction to Ecology',
#   'Published_date': '2023-04-24T14:30:04Z',
#   'Views': '98373',
#   'Likes': '2074'},
#  {'Title': 'Classification of Sedimentary Rocks Part 1: Terrigenous/Siliciclastic Rocks',
#   'Published_date': '2023-04-21T14:30:05Z',
#   'Views': '18117',
#   'Likes': '573'},
#  {'Title': 'Universal Basic Income (UBI)',
#   'Published_date': '2023-04-19T14:30:12Z',
#   'Views': '60453',
#   'Likes': '2253'},
#  {'Title': 'Organometallic Reactions Part 6: Metathesis Reactions',
#   'Published_date': '2023-04-17T14:30:21Z',
#   'Views': '13192',
#   'Likes': '297'},
#  {'Title': 'Classical Greek Philosophy: Socrates and Plato',
#   'Published_date': '2023-04-14T14:30:15Z',
#   'Views': '172070',
#   'Likes': '3725'},
#  {'Title': 'Laboratory Synthesis of Aspirin',
#   'Published_date': '2023-04-12T14:30:16Z',
#   'Views': '61873',
#   'Likes': '1593'},
#  {'Title': 'Mineralogy of Sedimentary Rocks: Weathering and Diagenesis',
#   'Published_date': '2023-04-10T14:30:00Z',
#   'Views': '15506',
#   'Likes': '521'},
#  {'Title': 'Reacting to Sadhguru and Frank Turek on Evolution (Collaboration with @scienceisdope )',
#   'Published_date': '2023-04-07T14:30:23Z',
#   'Views': '123672',
#   'Likes': '5434'},
#  {'Title': 'The Psychology of Humor: Why Are Things Funny?',
#   'Published_date': '2023-04-05T14:30:07Z',
#   'Views': '28997',
#   'Likes': '1523'},
#  {'Title': 'Organometallic Reactions Part 5: Nucleophilic/Electrophilic Attack on Ligands',
#   'Published_date': '2023-04-03T14:30:18Z',
#   'Views': '10816',
#   'Likes': '236'},
#  {'Title': 'Presocratics Part 2: Mathematics, Atoms, and Logic',
#   'Published_date': '2023-03-31T14:30:07Z',
#   'Views': '22750',
#   'Likes': '928'},
#  {'Title': 'Physically Constructing a Galvanic Cell (Electrochemistry)',
#   'Published_date': '2023-03-29T14:30:06Z',
#   'Views': '32676',
#   'Likes': '850'},
#  {'Title': 'Discussion on Critical Faculty Podcast (Evolution is Fact! - Featuring Aron Ra and Gutsick Gibbon)',
#   'Published_date': '2023-03-27T14:30:04Z',
#   'Views': '77243',
#   'Likes': '2712'},
#  {'Title': 'James Tour Debate Update!',
#   'Published_date': '2023-03-26T15:57:55Z',
#   'Views': '77845',
#   'Likes': '5489'},
#  {'Title': 'Characteristics of Sedimentary Rocks: Size, Provenance, and Composition',
#   'Published_date': '2023-03-24T14:30:05Z',
#   'Views': '17812',
#   'Likes': '569'},
#  {'Title': 'Phylum Rotifera Part 2: Four Major Clades',
#   'Published_date': '2023-03-22T14:30:13Z',
#   'Views': '8651',
#   'Likes': '333'},
#  {'Title': 'Organometallic Reactions Part 4: Migratory Insertions',
#   'Published_date': '2023-03-20T14:30:19Z',
#   'Views': '14166',
#   'Likes': '327'},
#  {'Title': 'Presocratics Part 1: Early Greek Philosophy',
#   'Published_date': '2023-03-17T14:30:05Z',
#   'Views': '55102',
#   'Likes': '1985'},
#  {'Title': '11 Types of Taxes: Sales, Income, Capital Gains, and More',
#   'Published_date': '2023-03-15T14:30:02Z',
#   'Views': '23710',
#   'Likes': '780'},
#  {'Title': "Reacting to iamLucid's Garbage Anti-Evolution Video",
#   'Published_date': '2023-03-13T14:30:04Z',
#   'Views': '1622611',
#   'Likes': '39735'},
#  {'Title': 'Performing Column Chromatography',
#   'Published_date': '2023-03-10T15:30:02Z',
#   'Views': '94063',
#   'Likes': '1961'},
#  {'Title': 'Classification of Igneous Rocks: Intrusive vs. Extrusive',
#   'Published_date': '2023-03-08T15:30:08Z',
#   'Views': '61961',
#   'Likes': '1226'},
#  {'Title': 'Phylum Rotifera Part 1: General Characteristics',
#   'Published_date': '2023-03-06T15:30:13Z',
#   'Views': '13279',
#   'Likes': '447'},
#  {'Title': 'Discussion on Wiser Tomorrow Podcast (Music, Channel History, James Tour, Science Denial, SciComm)',
#   'Published_date': '2023-03-03T15:30:03Z',
#   'Views': '16531',
#   'Likes': '760'},
#  {'Title': 'The Cognitive Basis of Superstition and Belief in the Supernatural',
#   'Published_date': '2023-03-01T15:30:08Z',
#   'Views': '74837',
#   'Likes': '5694'},
#  {'Title': 'Early Philosophical Thought (East Asia and India)',
#   'Published_date': '2023-02-27T15:30:07Z',
#   'Views': '41572',
#   'Likes': '2027'},
#  {'Title': 'Organometallic Reactions Part 3: Reductive Elimination',
#   'Published_date': '2023-02-24T15:30:06Z',
#   'Views': '14016',
#   'Likes': '311'},
#  {'Title': 'Phylum Micrognathozoa: Tiniest Invertebrates on Earth',
#   'Published_date': '2023-02-22T15:30:01Z',
#   'Views': '6718',
#   'Likes': '354'},
#  {'Title': 'Origin of Igneous Rocks',
#   'Published_date': '2023-02-20T15:38:11Z',
#   'Views': '45769',
#   'Likes': '1199'},
#  {'Title': 'Performing Thin Layer Chromatography (TLC)',
#   'Published_date': '2023-02-17T15:30:12Z',
#   'Views': '235818',
#   'Likes': '5093'},
#  {'Title': 'Federal Spending, Debt, and Deficits',
#   'Published_date': '2023-02-15T15:30:07Z',
#   'Views': '26276',
#   'Likes': '888'},
#  {'Title': 'Phylum Gnathostomulida: Jaw Worms',
#   'Published_date': '2023-02-13T15:30:07Z',
#   'Views': '7232',
#   'Likes': '328'},
#  {'Title': 'Debunking James Tour’s Latest Pathetic Series (Part 4 of 4)',
#   'Published_date': '2023-02-09T15:30:03Z',
#   'Views': '147057',
#   'Likes': '6368'},
#  {'Title': 'Debunking James Tour’s Latest Pathetic Series (Part 3 of 4)',
#   'Published_date': '2023-02-07T15:30:04Z',
#   'Views': '163154',
#   'Likes': '5610'},
#  {'Title': 'Diabetes and Insulin: A Triumph for Recombinant DNA Technology',
#   'Published_date': '2023-02-06T16:28:57Z',
#   'Views': '58888',
#   'Likes': '2846'},
#  {'Title': 'Introduction to Philosophy and Logic',
#   'Published_date': '2023-02-03T15:30:11Z',
#   'Views': '131396',
#   'Likes': '4918'},
#  {'Title': 'Debunking James Tour’s Latest Pathetic Series (Part 2 of 4)',
#   'Published_date': '2023-02-01T15:30:01Z',
#   'Views': '155097',
#   'Likes': '5914'},
#  {'Title': 'Debunking James Tour’s Latest Pathetic Series (Part 1 of 4)',
#   'Published_date': '2023-01-30T15:30:25Z',
#   'Views': '349797',
#   'Likes': '11894'},
#  {'Title': 'Titration of Strong Acid With Strong Base',
#   'Published_date': '2023-01-27T15:30:05Z',
#   'Views': '40397',
#   'Likes': '983'},
#  {'Title': 'Organometallic Reactions Part 2: Oxidative Addition',
#   'Published_date': '2023-01-25T15:30:15Z',
#   'Views': '20992',
#   'Likes': '422'},
#  {'Title': 'What is Happiness?',
#   'Published_date': '2023-01-23T15:30:15Z',
#   'Views': '46415',
#   'Likes': '1914'},
#  {'Title': 'Decongestants: Adrenergic Receptor Agonists',
#   'Published_date': '2023-01-20T15:30:00Z',
#   'Views': '17849',
#   'Likes': '569'},
#  {'Title': 'Types of Silicates Part 2: Inosilicates, Phyllosilicates, and Tectosilicates',
#   'Published_date': '2023-01-18T15:30:08Z',
#   'Views': '15841',
#   'Likes': '426'},
#  {'Title': 'Phylum Chaetognatha: Arrow Worms',
#   'Published_date': '2023-01-16T15:30:08Z',
#   'Views': '9380',
#   'Likes': '375'},
#  {'Title': 'Discussion On Jordan Harbinger Show (Post-Truth Era, Chemophobia, Alt-Health Quackery)',
#   'Published_date': '2023-01-13T15:30:06Z',
#   'Views': '24618',
#   'Likes': '903'},
#  {'Title': 'Organometallic Reactions Part 1: Ligand Substitution and the Trans Effect',
#   'Published_date': '2023-01-11T15:30:01Z',
#   'Views': '36786',
#   'Likes': '700'},
#  {'Title': 'Why Do We Have Central Banks?',
#   'Published_date': '2023-01-09T15:30:06Z',
#   'Views': '52716',
#   'Likes': '1765'},
#  {'Title': 'Pipettes and Standard Solutions',
# ...
#   'Views': '95937',
#   'Likes': '1760'},
#  {'Title': 'Practice Problem: ICE Box Calculations',
#   'Published_date': '2019-07-30T17:06:42Z',
#   'Views': '73766',
#   'Likes': '1165'},
#  {'Title': 'Subjunctive vs. Infinitive in Italian: Congiuntivo o Infinito?',
#   'Published_date': '2019-07-29T16:50:26Z',
#   'Views': '5876',
#   'Likes': '158'},
#  {'Title': 'Crystal Field Theory',
#   'Published_date': '2019-07-26T16:23:52Z',
#   'Views': '374722',
#   'Likes': '8945'},
#  {'Title': 'IIT/JEE Chemistry Practice #7: Molality/Mole Fraction',
#   'Published_date': '2019-07-25T16:27:53Z',
#   'Views': '3799',
#   'Likes': '115'},
#  {'Title': 'Diagonalization',
#   'Published_date': '2019-07-24T16:17:13Z',
#   'Views': '515968',
#   'Likes': '10281'},
#  {'Title': 'Practice Problem: Calculating Equilibrium Concentrations',
#   'Published_date': '2019-07-23T16:57:46Z',
#   'Views': '202616',
#   'Likes': '2104'},
#  {'Title': 'Subjunctive With Conjunctions in Italian: Congiuntivo con Congiunzioni',
#   'Published_date': '2019-07-22T15:20:45Z',
#   'Views': '6704',
#   'Likes': '187'},
#  {'Title': 'Coordination Compounds: Geometry and Nomenclature',
#   'Published_date': '2019-07-19T16:14:28Z',
#   'Views': '147828',
#   'Likes': '3511'},
#  {'Title': 'Professor Dave Debates Podcast #9 - How Should We Communicate Science?',
#   'Published_date': '2019-07-18T16:25:07Z',
#   'Views': '2151',
#   'Likes': '65'},
#  {'Title': 'Finding Eigenvalues and Eigenvectors',
#   'Published_date': '2019-07-17T16:17:57Z',
#   'Views': '817389',
#   'Likes': '16154'},
#  {'Title': 'Benjamin Harrison: Make Grandpa Proud (1889 - 1893)',
#   'Published_date': '2019-07-16T16:34:20Z',
#   'Views': '23744',
#   'Likes': '407'},
#  {'Title': 'Italian Vocabulary: Flowers and Trees',
#   'Published_date': '2019-07-15T18:00:55Z',
#   'Views': '4611',
#   'Likes': '124'},
#  {'Title': 'Professor Dave Debates Podcast #8 - Should We Start Fires?',
#   'Published_date': '2019-07-13T16:03:20Z',
#   'Views': '1762',
#   'Likes': '36'},
#  {'Title': 'Nucleophilic Aromatic Substitution',
#   'Published_date': '2019-07-12T16:36:16Z',
#   'Views': '59135',
#   'Likes': '1204'},
#  {'Title': 'IIT/JEE Chemistry Practice #6: Stoichiometry/Precipitation Reactions',
#   'Published_date': '2019-07-11T16:57:01Z',
#   'Views': '3145',
#   'Likes': '122'},
#  {'Title': 'Practice Problem: Initial Rates and Rate Laws',
#   'Published_date': '2019-07-09T16:20:08Z',
#   'Views': '50343',
#   'Likes': '899'},
#  {'Title': 'Past Subjunctive Tense in Italian: Congiuntivo Passato',
#   'Published_date': '2019-07-08T17:11:28Z',
#   'Views': '14508',
#   'Likes': '327'},
#  {'Title': 'The Common Ion Effect',
#   'Published_date': '2019-07-05T16:08:50Z',
#   'Views': '278510',
#   'Likes': '5513'},
#  {'Title': 'IIT/JEE Chemistry Practice #5: Oxidation Numbers',
#   'Published_date': '2019-07-04T17:08:42Z',
#   'Views': '4630',
#   'Likes': '168'},
#  {'Title': 'Practice Problem: Calculating Ionic Radius',
#   'Published_date': '2019-07-03T22:23:47Z',
#   'Views': '16376',
#   'Likes': '231'},
#  {'Title': 'The 10 Things That All Flat Earthers Say',
#   'Published_date': '2019-07-02T16:06:27Z',
#   'Views': '7702505',
#   'Likes': '225870'},
#  {'Title': 'Present Subjunctive Tense in Italian: Congiuntivo Presente',
#   'Published_date': '2019-07-01T15:37:50Z',
#   'Views': '32699',
#   'Likes': '703'},
#  {'Title': 'The Gram-Schmidt Process',
#   'Published_date': '2019-06-28T16:28:38Z',
#   'Views': '318584',
#   'Likes': '6423'},
#  {'Title': 'IIT/JEE Chemistry Practice #4: Limiting Reagents',
#   'Published_date': '2019-06-27T15:39:34Z',
#   'Views': '3684',
#   'Likes': '121'},
#  {'Title': 'Ask Professor Dave #4: Are You a Musician?',
#   'Published_date': '2019-06-26T15:05:01Z',
#   'Views': '26543',
#   'Likes': '1542'},
#  {'Title': "Practice Problem: Graham's Law of Effusion",
#   'Published_date': '2019-06-25T16:16:44Z',
#   'Views': '46030',
#   'Likes': '673'},
#  {'Title': 'The Subjunctive Mood in Italian: Il Congiuntivo',
#   'Published_date': '2019-06-24T17:03:58Z',
#   'Views': '22745',
#   'Likes': '643'},
#  {'Title': 'Selective Precipitation',
#   'Published_date': '2019-06-21T06:19:24Z',
#   'Views': '46149',
#   'Likes': '973'},
#  {'Title': 'IIT/JEE Chemistry Practice #3: Empirical/Molecular Formula',
#   'Published_date': '2019-06-20T16:40:03Z',
#   'Views': '3993',
#   'Likes': '123'},
#  {'Title': 'Professor Dave Debates Podcast #7 - Are We All Mentally Ill?',
#   'Published_date': '2019-06-19T23:55:57Z',
#   'Views': '3785',
#   'Likes': '87'},
#  {'Title': 'Practice Problem: Density of a Gas',
#   'Published_date': '2019-06-18T16:40:27Z',
#   'Views': '11336',
#   'Likes': '174'},
#  {'Title': 'Italian Vocabulary: Going Shopping',
#   'Published_date': '2019-06-17T17:14:14Z',
#   'Views': '8016',
#   'Likes': '175'},
#  {'Title': 'Orthogonality and Orthonormality',
#   'Published_date': '2019-06-14T16:35:51Z',
#   'Views': '198684',
#   'Likes': '4318'},
#  {'Title': 'IIT/JEE Chemistry Practice #2: Molar Mass/Stoichiometry',
#   'Published_date': '2019-06-13T15:22:53Z',
#   'Views': '6428',
#   'Likes': '204'},
#  {'Title': 'Grover Cleveland: White House Wedding (1885 - 1889)',
#   'Published_date': '2019-06-12T16:07:22Z',
#   'Views': '19890',
#   'Likes': '388'},
#  {'Title': "IIT/JEE Chemistry Practice #1: Avogadro's Number/Moles",
#   'Published_date': '2019-06-11T16:12:34Z',
#   'Views': '38440',
#   'Likes': '850'},
#  {'Title': 'Gerunds in the Italian Language',
#   'Published_date': '2019-06-10T16:46:15Z',
#   'Views': '9915',
#   'Likes': '286'},
#  {'Title': 'Professor Dave Debates Podcast #6 - Is the Earth Flat?',
#   'Published_date': '2019-06-07T15:56:37Z',
#   'Views': '90531',
#   'Likes': '1371'},
#  {'Title': 'Predicting Precipitation With Ksp Values',
#   'Published_date': '2019-06-05T19:08:30Z',
#   'Views': '84204',
#   'Likes': '1601'},
#  {'Title': 'Practice Problem: Molar Mass of a Gas',
#   'Published_date': '2019-06-04T16:26:38Z',
#   'Views': '16248',
#   'Likes': '249'},
#  {'Title': 'Italian Grammar: Verbi Pronominali - Volerci e Metterci',
#   'Published_date': '2019-06-03T17:39:30Z',
#   'Views': '7444',
#   'Likes': '197'},
#  {'Title': 'Solubility Product Constant (Ksp)',
#   'Published_date': '2019-05-31T15:56:02Z',
#   'Views': '346352',
#   'Likes': '7034'},
#  {'Title': 'A Tour of the Universe With Space Engine (Part 2)',
#   'Published_date': '2019-05-30T16:42:29Z',
#   'Views': '15976',
#   'Likes': '340'},
#  {'Title': 'Image and Kernel',
#   'Published_date': '2019-05-29T17:19:17Z',
#   'Views': '167390',
#   'Likes': '3976'},
#  {'Title': 'Practice Problem: Gravimetric Analysis',
#   'Published_date': '2019-05-28T16:43:36Z',
#   'Views': '223073',
#   'Likes': '3333'},
#  {'Title': 'Past Absolute Tense in Italian: Passato Remoto',
#   'Published_date': '2019-05-27T16:45:37Z',
#   'Views': '26815',
#   'Likes': '693'},
#  {'Title': 'Professor Dave Debates Podcast #5 - Is Big Pharma Evil?',
#   'Published_date': '2019-05-25T16:55:49Z',
#   'Views': '4833',
#   'Likes': '75'},
#  {'Title': 'Types of Colloids and Their Properties',
#   'Published_date': '2019-05-24T16:57:48Z',
#   'Views': '193232',
#   'Likes': '4054'},
#  {'Title': 'The Human Reproductive System',
#   'Published_date': '2019-05-23T16:43:07Z',
#   'Views': '329288',
#   'Likes': '4930'},
#  {'Title': "Response to Globebusters - The Earth Still Isn't Flat",
#   'Published_date': '2019-05-22T15:59:24Z',
#   'Views': '14495783',
#   'Likes': '324565'},
#  {'Title': 'Practice Problem: Colligative Properties',
#   'Published_date': '2019-05-21T16:00:08Z',
#   'Views': '49312',
#   'Likes': '734'},
#  {'Title': 'Relative Pronouns in Italian: Chi',
#   'Published_date': '2019-05-20T17:27:50Z',
#   'Views': '8935',
#   'Likes': '239'},
#  {'Title': 'Practice Problem: Molarity Calculations',
#   'Published_date': '2019-05-17T16:21:42Z',
#   'Views': '26056',
#   'Likes': '349'},
#  {'Title': 'The Urinary System',
#   'Published_date': '2019-05-16T15:45:45Z',
#   'Views': '250217',
#   'Likes': '5101'},
#  {'Title': 'Linear Transformations on Vector Spaces',
#   'Published_date': '2019-05-15T16:24:53Z',
#   'Views': '220014',
#   'Likes': '4531'},
#  {'Title': 'Chester A. Arthur: Turning Tables (1881 - 1885)',
#   'Published_date': '2019-05-14T16:24:57Z',
#   'Views': '17123',
#   'Likes': '322'},
#  {'Title': 'Relative Pronouns in Italian: Il Quale',
#   'Published_date': '2019-05-13T17:39:05Z',
#   'Views': '9532',
#   'Likes': '240'},
#  {'Title': 'Viscosity, Cohesive and Adhesive Forces, Surface Tension, and Capillary Action',
#   'Published_date': '2019-05-10T16:53:45Z',
#   'Views': '544804',
#   'Likes': '13260'},
#  {'Title': 'The Digestive System',
#   'Published_date': '2019-05-09T20:48:39Z',
#   'Views': '850696',
#   'Likes': '13301'},
#  {'Title': 'A Tour of the Universe With Space Engine (Part 1)',
#   'Published_date': '2019-05-08T18:12:52Z',
#   'Views': '33570',
#   'Likes': '786'},
#  {'Title': 'Practice Problem: Dilution Calculations',
#   'Published_date': '2019-05-07T17:00:03Z',
#   'Views': '69126',
#   'Likes': '758'},
#  {'Title': 'Relative Pronouns in Italian: Che and Cui',
#   'Published_date': '2019-05-06T17:57:29Z',
#   'Views': '27293',
#   'Likes': '691'},
#  {'Title': 'Professor Dave Debates Podcast #4 - Sexual Consent: Absolutism vs. Relativism',
#   'Published_date': '2019-05-04T17:47:44Z',
#   'Views': '5342',
#   'Likes': '89'},
#  {'Title': 'Non-Ideal Gases and the Van der Waals Equation',
#   'Published_date': '2019-05-03T16:06:55Z',
#   'Views': '187945',
#   'Likes': '4185'},
#  {'Title': 'The Respiratory System',
#   'Published_date': '2019-05-02T15:03:53Z',
#   'Views': '932701',
#   'Likes': '14463'},
#  {'Title': 'Change of Basis',
#   'Published_date': '2019-05-01T16:41:44Z',
#   'Views': '240482',
#   'Likes': '3747'},
#  {'Title': 'Practice Problem: Enthalpy of Vaporization',
#   'Published_date': '2019-04-30T15:58:20Z',
#   'Views': '47102',
#   'Likes': '518'},
#  {'Title': 'Idiomatic Superlatives in Italian',
#   'Published_date': '2019-04-29T14:49:32Z',
#   'Views': '3790',
#   'Likes': '115'},
#  {'Title': 'Practice Problem: Enthalpy of Combustion',
#   'Published_date': '2019-04-26T17:12:35Z',
#   'Views': '39910',
#   'Likes': '478'},
#  {'Title': 'The Immune System: Innate Defenses and Adaptive Defenses',
#   'Published_date': '2019-04-25T17:33:47Z',
#   'Views': '501438',
#   'Likes': '10864'},
#  {'Title': 'Basis and Dimension',
#   'Published_date': '2019-04-24T15:51:08Z',
#   'Views': '525260',
#   'Likes': '8870'},
#  {'Title': "Practice Problem: Hess's Law",
#   'Published_date': '2019-04-23T16:32:03Z',
#   'Views': '60640',
#   'Likes': '1223'},
#  {'Title': 'Italian Grammar: Past Conditional With Modal Verbs',
#   'Published_date': '2019-04-22T16:34:41Z',
#   'Views': '6922',
#   'Likes': '163'},
#  {'Title': 'Practice Problem: Calorimetry and Specific Heat',
#   'Published_date': '2019-04-20T01:47:13Z',
#   'Views': '23079',
#   'Likes': '337'},
#  {'Title': 'The Circulatory System Part 3: The Lymphatic System',
#   'Published_date': '2019-04-18T16:55:59Z',
#   'Views': '153225',
#   'Likes': '2905'},
#  {'Title': 'Professor Dave Debates Podcast #3 - Climate Change: How Do We Know?',
#   'Published_date': '2019-04-17T18:02:42Z',
#   'Views': '8752',
#   'Likes': '152'},
#  {'Title': 'Linear Independence',
#   'Published_date': '2019-04-16T16:21:32Z',
#   'Views': '577486',
#   'Likes': '10572'},
#  {'Title': 'Italian Grammar: Present Conditional With Modal Verbs',
#   'Published_date': '2019-04-15T15:36:04Z',
#   'Views': '7736',
#   'Likes': '196'},
#  {'Title': 'Measuring Pressure With Barometers and Manometers',
#   'Published_date': '2019-04-12T16:32:47Z',
#   'Views': '201268',
#   'Likes': '4085'},
#  {'Title': 'The Circulatory System Part 2: Blood Vessels',
#   'Published_date': '2019-04-11T15:18:34Z',
#   'Views': '307646',
#   'Likes': '5793'},
#  {'Title': 'Separating Liquids by Distillation',
#   'Published_date': '2019-04-10T14:58:56Z',
#   'Views': '406200',
#   'Likes': '6186'},
#  {'Title': 'James Garfield: What Could Have Been? (1881)',
#   'Published_date': '2019-04-09T16:17:15Z',
#   'Views': '22239',
#   'Likes': '473'},
#  {'Title': 'Past Conditional Tense in Italian: Condizionale Passato',
#   'Published_date': '2019-04-08T16:29:53Z',
#   'Views': '22858',
#   'Likes': '494'},
#  {'Title': 'Professor Dave Debates Podcast #2 - Interpretations of Quantum Mechanics',
#   'Published_date': '2019-04-07T17:09:13Z',
#   'Views': '4758',
#   'Likes': '88'},
#  {'Title': 'Practice Problem: VSEPR Theory and Molecular Geometry',
#   'Published_date': '2019-04-06T16:34:35Z',
#   'Views': '34163',
#   'Likes': '601'},
#  {'Title': 'The Circulatory System Part 1: The Heart',
#   'Published_date': '2019-04-04T17:54:32Z',
#   'Views': '929561',
#   'Likes': '15154'},
#  {'Title': 'Astrology: Fact or Fiction?',
#   'Published_date': '2019-04-03T16:04:31Z',
#   'Views': '1009822',
#   'Likes': '34364'},
#  {'Title': 'Practice Problem: Naming Ionic Compounds',
#   'Published_date': '2019-04-02T17:00:39Z',
#   'Views': '27893',
#   'Likes': '401'},
#  {'Title': 'Present Conditional Tense in Italian: Condizionale Presente',
#   'Published_date': '2019-04-01T17:24:12Z',
#   'Views': '43703',
#   'Likes': '950'},
#  {'Title': 'Practice Problem: Lattice Energy and Ionic Bond Strength',
#   'Published_date': '2019-03-29T20:23:14Z',
#   'Views': '112908',
#   'Likes': '2110'},
#  {'Title': 'The Composition and Function of Blood',
#   'Published_date': '2019-03-28T16:31:22Z',
#   'Views': '696777',
#   'Likes': '13684'},
#  {'Title': 'The Earth is Definitely Not Flat',
#   'Published_date': '2019-03-27T17:22:35Z',
#   'Views': '2137410',
#   'Likes': '63261'},
#  {'Title': 'Subspaces and Span',
#   'Published_date': '2019-03-26T15:59:30Z',
#   'Views': '323034',
#   'Likes': '6900'},
#  {'Title': 'What Sounds do Italian Animals Make?',
#   'Published_date': '2019-03-25T16:41:03Z',
#   'Views': '9255',
#   'Likes': '135'},
#  {'Title': 'Professor Dave Debates Podcast #1 - Will Artificial Intelligence Destroy Humanity?',
#   'Published_date': '2019-03-23T17:37:10Z',
#   'Views': '14124',
#   'Likes': '173'},
#  {'Title': 'Examples of s-p Mixing in Molecular Orbital Theory',
#   'Published_date': '2019-03-22T16:32:54Z',
#   'Views': '115381',
#   'Likes': '3107'},
#  {'Title': 'The Endocrine System',
#   'Published_date': '2019-03-21T16:22:56Z',
#   'Views': '702924',
#   'Likes': '14725'},
#  {'Title': 'The Future Colonization of Space: Terraforming and Dyson Spheres',
#   'Published_date': '2019-03-20T15:37:22Z',
#   'Views': '73387',
#   'Likes': '2543'},
#  {'Title': 'Column Chromatography',
#   'Published_date': '2019-03-19T17:24:28Z',
#   'Views': '256429',
#   'Likes': '5056'},
#  {'Title': 'Negatives in Italian',
#   'Published_date': '2019-03-18T17:04:32Z',
#   'Views': '8948',
#   'Likes': '238'},
#  {'Title': 'Practice Problem: Ionization Energy',
#   'Published_date': '2019-03-15T17:15:56Z',
#   'Views': '107670',
#   'Likes': '1435'},
#  {'Title': 'The Autonomic Nervous System: Sympathetic and Parasympathetic Divisions',
#   'Published_date': '2019-03-14T15:48:05Z',
#   'Views': '999560',
#   'Likes': '23163'},
#  {'Title': 'Astrobiology: The Search for Extraterrestrial Life',
#   'Published_date': '2019-03-13T15:54:50Z',
#   'Views': '61052',
#   'Likes': '2011'},
#  {'Title': 'Understanding Vector Spaces',
#   'Published_date': '2019-03-12T15:56:06Z',
#   'Views': '575528',
#   'Likes': '11675'},
#  {'Title': 'Indefinites in Italian: Pronomi e Aggettivi Indefiniti',
#   'Published_date': '2019-03-11T16:14:49Z',
#   'Views': '9664',
#   'Likes': '228'},
#  {'Title': 'Practice Problem: Atomic Radii and Ionic Radii',
#   'Published_date': '2019-03-08T16:24:58Z',
#   'Views': '80610',
#   'Likes': '1401'},
#  {'Title': 'The Peripheral Nervous System: Nerves and Sensory Organs',
#   'Published_date': '2019-03-07T16:20:53Z',
#   'Views': '299359',
#   'Likes': '5414'},
#  {'Title': 'The End of the Universe: Hot or Cold?',
#   'Published_date': '2019-03-06T17:44:25Z',
#   'Views': '47489',
#   'Likes': '1500'},
#  {'Title': 'Rutherford B. Hayes: His Fraudulency (1877 - 1881)',
#   'Published_date': '2019-03-05T17:48:13Z',
#   'Views': '27783',
#   'Likes': '459'},
#  {'Title': 'Italian Vocabulary: Nations and Nationalities',
#   'Published_date': '2019-03-04T18:26:11Z',
#   'Views': '15862',
#   'Likes': '344'},
#  {'Title': 'Thin Layer Chromatography (TLC)',
#   'Published_date': '2019-03-01T17:34:41Z',
#   'Views': '362205',
#   'Likes': '8104'},
#  {'Title': 'The Central Nervous System: The Brain and Spinal Cord',
#   'Published_date': '2019-02-28T14:24:49Z',
#   'Views': '450903',
#   'Likes': '7536'},
#  ...]

# %%
Video_data=pd.DataFrame(Video_details)

Video_data['Published_date'] =pd.to_datetime(Video_data['Published_date']).dt.date#remove timestamp for publication and only leaves date
Video_data['Views']= pd.to_numeric(Video_data['Views'])#changes the following to numeric values instead of string
Video_data['Likes']= pd.to_numeric(Video_data['Likes'])
#Video_data['Comments']= pd.to_numeric(Video_data['Comments'])

Video_data
# Out:
#                                                   Title Published_date  \
# 0      Bret and Eric Weinstein: Brothers in Fraudulence     2024-09-27
# 1     Ancient Mesopotamia Part 1: The Sumerians  (41...     2024-09-25
# 2     The Definitive Guide to Debunking Creationists...     2024-09-23
# 3     Subphylum Myriapoda Part 2: Diversity of Centi...     2024-09-20
# 4                    Homo sapiens: Last of the Hominins     2024-09-18
# ...                                                 ...            ...
# 1578                                       SN1 Reaction     2015-01-05
# 1579                          Free Radical Halogenation     2015-01-05
# 1580                            Oxidation and Reduction     2015-01-05
# 1581                                 Addition Reactions     2015-01-05
# 1582                          Friedel-Crafts Alkylation     2015-01-05
#
#        Views  Likes
# 0     233190  14424
# 1      20788   1574
# 2      53579   4399
# 3      19438    420
# 4      21924   1705
# ...      ...    ...
# 1578  313848   4966
# 1579  137739   2053
# 1580  102276   1822
# 1581  205135   2541
# 1582  155206   2858
#
# [1583 rows x 4 columns]

# %%
Top_videos = Video_data.sort_values(by='Views', ascending=False)#add .head(x) to cap the number of videos

Top_videos #Outputs videos based on views
# Out:
#                                                  Title Published_date  \
# 937  Response to Globebusters - The Earth Still Isn...     2019-05-22
# 908           The 10 Things That All Flat Earthers Say     2019-07-02
# 748                    10 Challenges For Flat Earthers     2020-02-28
# 436  Professor Dave Humiliates Flat Earther David W...     2022-04-08
# 642  Destroying Flat Earth Without Using Science - ...     2020-10-02
# ..                                                 ...            ...
# 36    AP Chemistry Long Answer Question 3 (Equilibria)     2024-08-19
# 31   AP Chemistry Long Answer Question 8 (Gas Produ...     2024-08-19
# 27   AP Chemistry Long Answer Question 12 (Lattice ...     2024-08-19
# 32   AP Chemistry Long Answer Question 7 (Gas Colle...     2024-08-19
# 26     AP Chemistry Long Answer Question 13 (Polymers)     2024-08-19
#
#         Views   Likes
# 937  14495783  324565
# 908   7702505  225870
# 748   7539607  295281
# 436   5773474  100382
# 642   5157855  156189
# ..        ...     ...
# 36          3       1
# 31          3       1
# 27          3       1
# 32          2       1
# 26          2       1
#
# [1583 rows x 4 columns]

# %%
#Top_videos.to_csv('Video_Details(Khan Academy).csv')
