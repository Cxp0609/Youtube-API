# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key='AIzaSyA2Ul6y5si8BqkydGb5TdDzwRKhUw8IyCU'
#channel_id='UCnz-ZXXER4jOvuED5trXfEA'#Null code
#the following are the channel ids found within the source code
channel_ids=['UC0cd_-e49hZpWLH3UIwoWRA',#Professor Dave Explains     contains various college level subect such as math English lating sciece Phsycology etc.    //Note comments are blocked on some videos meaning they have to be ommited in the statics for this channel
             'UCdngmbVKX1Tgre699-XLlUA',#TechWorld with Nana      Professional tips for a carrer in Computer Science/Eingeneering with cousre on common tools used
             'UC4SVo0Ue36XCfOyb5Lh1viQ',#Bro Code      Contains courses on programming languages
             'UCEWpbFLzoYGPfuWUMFPSaoA', #The Organic Chemistry Tutor    College Level Math/Science Channel    
             'UCWv7vMbMWH4-V0ZXdmDpPBA']#Programming with Moash   Miscellaneous programming tips and courses

youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# Function to get Channel Statistics

# %%
def get_channel_stats(youtube, channel_ids):
     all_data=[]
     request = youtube.channels().list(
          part='snippet,contentDetails,statistics',
          id=','.join(channel_ids))
     response = request.execute()#Null code

     for i in range (len(response['items'])): # gets desired content from each item in channel_ids
          data = dict(Channel_name = response['items'][i]['snippet'] ['title'], 
                    Subcribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics'] ['viewCount'],
                    Total_videos = response['items'][i]['statistics'] ['videoCount'],
                    playlist_id = response ['items'][i]['contentDetails'] ['relatedPlaylists']['uploads'])#gets upload id
          all_data.append(data)

     return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_data=pd.DataFrame(channel_statistics)
channel_data
# Out:
#                   Channel_name Subcribers       Views Total_videos  \
# 0      Professor Dave Explains    3390000   345719647         1623
# 1        Programming with Mosh    4200000   218107921          235
# 2                     Bro Code    2250000   119963186          831
# 3  The Organic Chemistry Tutor    8580000  1335710915         2843
# 4          TechWorld with Nana    1150000    61185116          123
#
#                 playlist_id
# 0  UU0cd_-e49hZpWLH3UIwoWRA
# 1  UUWv7vMbMWH4-V0ZXdmDpPBA
# 2  UU4SVo0Ue36XCfOyb5Lh1viQ
# 3  UUEWpbFLzoYGPfuWUMFPSaoA
# 4  UUdngmbVKX1Tgre699-XLlUA

# %%
channel_data['Subcribers'] = pd.to_numeric(channel_data['Subcribers'] )
channel_data['Views'] = pd.to_numeric(channel_data['Views'] )
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'] )

# %%
channel_data.dtypes
# Out:
# Channel_name    object
# Subcribers       int64
# Views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %% [markdown]
# The following are just graphs and charts used to test outputs

# %%
#sns.set(rc={'figure.figsize':(10,8)})
#ax = sns.barplot(x='Channel_name', y='Subcribers', data=channel_data)

# %%
#ax = sns.barplot(x='Channel_name', y='Views', data=channel_data)

# %%
#ax = sns.barplot(x='Channel_name', y='Total_videos', data=channel_data)

# %% [markdown]
# Function to get video ids

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=="Programming with Mosh", 'playlist_id'].iloc[0] #the channel_name has to be changed to a valid name found in the channel_id
playlist_id #this is the id of the playlist that contains all videos on a channel
# Out:
# 'UUWv7vMbMWH4-V0ZXdmDpPBA'

# %%
def get_video_ids(youtube, playlist_id):

    request = youtube.playlistItems().list(
            part='contentDetails',
            playlistId = playlist_id,
            maxResults = 50)#results per page
    
    response = request.execute()#returns json formaat file

    video_ids = []
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True

    while more_pages:#this loop checks if there are anymore videos on the channel
        if next_page_token is None: 
            more_pages =False
        else:
            request = youtube.playlistItems().list(part='contentDetails',
            playlistId = playlist_id,
            maxResults = 50,#results per page
            pageToken = next_page_token)

            response = request.execute()

            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')



    return (video_ids) #returns the id of every video in the youtube channel

# %%
video_ids = get_video_ids(youtube, playlist_id)

video_ids #outputs the id of every youtube video found in a channel
# Out:
# ['yVl_G-F7m8c',
#  '3qXYA52uTew',
#  'p4-imHH_xiw',
#  '6GQRb4fGvtk',
#  'YRJbhFLLPyE',
#  '9R3X0JoCLyU',
#  'GxmfcnU3feo',
#  '7IgVGSaQPaw',
#  '3ZEMvvDFEdA',
#  'yye7rSsiV6k',
#  'IQDA39A44AA',
#  'CxLdTIIMXuM',
#  'OeEHJgzqS1k',
#  'Tef1e9FiSR0',
#  'J-graiyPhpw',
#  '6xrkbN6vz9U',
#  '3WphgC4wq0I',
#  '7IoNR3q2Jcc',
#  'tdFsel6-bgo',
#  '1mD7-WWKvto',
#  '8jP78iP6zVM',
#  'Zl1hnNOAbFQ',
#  '9d5JkpY_4PU',
#  'cVMh0SIjp9k',
#  'iw0znRuaYL8',
#  'p-h1LpM1xm4',
#  'KkmSR7c9qLc',
#  'W2KOSaetWBk',
#  'btpWt1Cas2I',
#  '4gX44uyGSHo',
#  'FW49JfEXI3E',
#  'Vrtx9G9lEuM',
#  'vE7Cy5csYbQ',
#  'TeQd4kOh3ow',
#  'nzzPMc1X_gM',
#  'cTlkarcQhZU',
#  '27YP6n6pDh0',
#  'XyayvDGKSfM',
#  'kJOqIaGwQ7Y',
#  'E9BXvDElDlw',
#  '-mA2HV1f4Go',
#  'eImSRSe4JYQ',
#  'vXYIwSrDFbg',
#  'XKkoVpupYdw',
#  'tfGzvBaZAR4',
#  'GR2fdYBQfU0',
#  'jt41xX_SMtA',
#  'HXH4yu227EQ',
#  'TJgFAOJsasA',
#  'NJzlY_NgxDc',
#  '80FYJ9BEqxs',
#  '8Xwq35cPwYg',
#  'gBNF51jchgg',
#  'zuKbR4Q428o',
#  'qngnPz_gDjo',
#  '8EQshxtk-iA',
#  'B5Kh0kZ-gA8',
#  'J9sfR6HN6BY',
#  'ZVnjOPwW4ZA',
#  'QHBVA_7bSRg',
#  'SqcY0GlETPk',
#  'sTeoEFzVNSc',
#  'uN6JO-5GW8w',
#  'FhyHvFXXkbo',
#  'ZzaPdXTrSb8',
#  'd56mG7DezGs',
#  'HG6yIjZapSA',
#  'rH0winlka8A',
#  '7i3Rliqzquw',
#  'JFuMei9Wwk4',
#  '_nmm0nZqIIY',
#  'Sf8vefrS5PQ',
#  'LxQe4TqDdAU',
#  'KaVlRUvwvNk',
#  'rHux0gMZ3Eg',
#  'pTFZFxd4hOI',
#  'Eo90IEphG_M',
#  'qz0aGYrrlhU',
#  '-_X6PhkjpzU',
#  'Nb0btdq1164',
#  '1GlJnq-24uU',
#  '2ReR1YJrNOM',
#  '7eh4d6sabA0',
#  'kqtD5dpn9C8',
#  '8JJ101D3knE',
#  'uxZZzmeCoLE',
#  '6oFuwhIibo4',
#  'nKzEJWbkPbQ',
#  'uJLwnsLn0_Q',
#  '0-S5a0eXPoc',
#  'poQXNp9ItL4',
#  'bjFvcFjJpE0',
#  'NU_1StN5Tkk',
#  '8TnBZ8rom9c',
#  'QAs25_hMhZY',
#  'q4MEKTVxg0c',
#  'BBpAmxU_NQo',
#  'cifiry8yoao',
#  'XBoZPCgdnm8',
#  'eIrMbAQSU34',
#  'i8xsbYgMiBs',
#  'pEbIhUySqbk',
#  '7S_tz1z_5bA',
#  '_uQrJ0TkZlc',
#  'r16Rn4_jDfk',
#  'stZU1tJzHrA',
#  'z3-XFI_nXNM',
#  '3Tcq_dBhIrQ',
#  '2qKQGqpRsks',
#  'HLy_wLI6juc',
#  't9j8lCUGZXo',
#  'OxUsVif94aI',
#  'NKmasqr_Xkw',
#  'cQT33yu9pY8',
#  'Ctqi5Y4X-jA',
#  '9OeznAkyQz4',
#  'Zp5MuPOtsSY',
#  'u-OmVr_fT4s',
#  '94UHCEmprCY',
#  'ODjFDZC_TyA',
#  '9ueMumuFv6g',
#  'tsBy6je8KjM',
#  'Y8Tko2YC5hA',
#  'f79MRyMsjrQ',
#  'yE9v9rt6ziw',
#  'Ke90Tje7VS0',
#  'NCwa_xi0Uuc',
#  'N3AkSS5hXMA',
#  'rNmxANyH0BU',
#  'mesu75PTDC8',
#  'XgSjoHgy3Rk',
#  'g1C40tDP0Bk',
#  'G3BS3sh3D8Q',
#  '4_iT6EGkQfk',
#  'NgF9-pdTDGs',
#  '09BwruU4kiY',
#  'gvicrj31JOM',
#  'H1NmJIv1A2Y',
#  'iJKkZA215tQ',
#  'fD0t_DKREbE',
#  'N8ap4k_1QEQ',
#  'bl98dm7vJt0',
#  'oigfaZ5ApsM',
#  's9wW2PpJsmQ',
#  '23AOrSN-wmI',
#  'jpegXpQpb3o',
#  'IsG4Xd6LlsM',
#  'upDLs1sn7g4',
#  'W6NZfCO5SIk',
#  'PFmuCDHHpwk',
#  'pTB0EiLXUC8',
#  'pKd0Rpw7O48',
#  'TlB_eWDSMt4',
#  'VLXAzzRjQws',
#  '9ErAONqE6HE',
#  'V2gVOIyUqVs',
#  'l20MBBFZAmA',
#  'IbgZASv0hc8',
#  'j95Lwxvi9JY',
#  'WlWdbtJoCLQ',
#  '44b6CDDnDPg',
#  'Cxo4UKpHv5s',
#  '9Amxzvq5LY8',
#  'jn8PZNBmKm0',
#  'KvG0a9dY3UI',
#  'qZQmCfkmbNA',
#  'jOupHNvDIq8',
#  'XUSHH0E-7zk',
#  'uVwtVBpw7RQ',
#  'SLwpqD8n3d0',
#  'H5ySG5364uE',
#  'fo6rvTP9kkc',
#  '_TxOmmJTd98',
#  'aQ8YkJrAbzE',
#  '56bbjE4assU',
#  'vpT4-7YdV7M',
#  'q7aWkjH3UUI',
#  '4_J_CLKwoto',
#  'ZqDtPFrUonQ',
#  'HYrXogLj7vg',
#  'ocz2Ml5Wg9g',
#  'gK21_9QuthM',
#  'tUCa3JcFILI',
#  'LtT01ZCHRjk',
#  'hAaoPOx_oIw',
#  'vwyvMZStS54',
#  'mqWXRX5fxGQ',
#  'ra5qNKNc95U',
#  'wPT3K3w6JtU',
#  '9AaRJ8COXdM',
#  'k5E2AVpwsko',
#  'azCCiJJjKr4',
#  'tiWqCBXnWj0',
#  'P17bFRuefjA',
#  'W9Ah_ZDFc1c',
#  'QygRnETpBIg',
#  'NjN00cM18Z4',
#  '8Wyc2XuBkQg',
#  'AsB54HC7MV4',
#  'c0UdqoRT_Xg',
#  'WjcL09xgo3o',
#  'ZX7_12fwQLU',
#  'yt8lqei9xyg',
#  'Q1uORsKjrMo',
#  'yG4FH60fhUE',
#  'UEcdQR-NoNA',
#  'e-_mDyqm2oU',
#  '93ZU6j59wL4',
#  'yBxPgF85vt4',
#  'E7Voso411Vs',
#  'bevlMOzaFTc',
#  'gfkTfcpWqAY',
#  'SRn_E6juCVE',
#  'CaspUXvVVG4',
#  '_-CD_5YhJTA',
#  'rtXpYpZdOzM',
#  'u-HdLtqEOog',
#  'gyal6TbgmSU',
#  'jQgwEsJISy0',
#  '5koPpYVa020',
#  'BFAGGPgi0ec',
#  'kh6ehZ1BCUk',
#  'tTRy_GluLac',
#  'dC0LVPZedZA',
#  'QkHeKnjNuWA',
#  'QASCp8PyRXM',
#  'jbiqBchPfKw',
#  'NjCF_7bpKjw',
#  'ZnGP9ScI9pc',
#  'AvhdNKmmAXU',
#  '4t0n5k0X7ow',
#  'FfQT31gZWp8',
#  'niYCJOMZPJw',
#  'FXlSC1gcs7E',
#  'IPc1HP1QAog',
#  'JhxC-K-Eehg']

# %% [markdown]
# Function to get video details

# %%
def get_video_details(youtube, video_ids):

    all_video_stats=[]
    for i in range (0,len(video_ids), 50):
        request = youtube.videos().list(
            part='snippet,statistics',
            id=','.join(video_ids[i:i+50])) #returns the vidoe details as a string and goes through 50 videos at a time
        response = request.execute() #returns json format file

        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                               Published_date= video['snippet']['publishedAt'],
                               Views=video['statistics']['viewCount'],
                               Likes=video['statistics']['likeCount'],
                              #dislikes are no longer availible on youtube API and are replaced with favoriteCount
                               #Comments=video['statistics']['commentCount'], #Note some channels disable comments
                               #description= video['snippet']['description']  # the description funtion works bun in the interest of the API Quaota it is commented out currently
                               )
            all_video_stats.append(video_stats)
                               
    return all_video_stats

# %%
Video_details = get_video_details(youtube, video_ids)
Video_details #outputs desired details from video
# Out:
# [{'Title': 'Python Projects for Beginners – Master Problem-Solving! 🚀',
#   'Published_date': '2024-09-10T13:01:00Z',
#   'Views': '89884',
#   'Likes': '3433'},
#  {'Title': 'Big Update: Watch My Videos in Your Language!',
#   'Published_date': '2024-09-09T18:21:49Z',
#   'Views': '29155',
#   'Likes': '1073'},
#  {'Title': 'Get Ready for Something Special – Announcement Inside!',
#   'Published_date': '2024-09-06T13:00:07Z',
#   'Views': '23943',
#   'Likes': '1247'},
#  {'Title': 'The Complete DevOps Roadmap [2024]',
#   'Published_date': '2024-08-15T13:00:08Z',
#   'Views': '152186',
#   'Likes': '5386'},
#  {'Title': 'The Complete Data Analyst Roadmap [2024]',
#   'Published_date': '2024-08-06T13:00:37Z',
#   'Views': '126569',
#   'Likes': '4201'},
#  {'Title': 'The Complete Data Science Roadmap [2024]',
#   'Published_date': '2024-08-01T13:00:08Z',
#   'Views': '136516',
#   'Likes': '5516'},
#  {'Title': 'The Complete Web Development Roadmap [2024]',
#   'Published_date': '2024-07-25T13:00:16Z',
#   'Views': '214928',
#   'Likes': '8505'},
#  {'Title': 'The Complete Machine Learning Roadmap [2024]',
#   'Published_date': '2024-07-18T13:00:06Z',
#   'Views': '219095',
#   'Likes': '8809'},
#  {'Title': 'Become a Mobile Developer in 12 Months! 🚀',
#   'Published_date': '2024-07-11T13:00:07Z',
#   'Views': '12724',
#   'Likes': '734'},
#  {'Title': 'The Complete App Development Roadmap [2024]',
#   'Published_date': '2024-07-04T13:01:03Z',
#   'Views': '304329',
#   'Likes': '9527'},
#  {'Title': 'Become a Back-end Developer in 12 Months! 🚀',
#   'Published_date': '2024-06-19T13:00:24Z',
#   'Views': '21829',
#   'Likes': '1272'},
#  {'Title': 'Become a Frontend Developer in 12 Months! 🚀',
#   'Published_date': '2024-06-12T13:00:21Z',
#   'Views': '24246',
#   'Likes': '1133'},
#  {'Title': 'The Complete Backend Developer Roadmap [2024]',
#   'Published_date': '2024-06-11T13:00:30Z',
#   'Views': '256904',
#   'Likes': '8719'},
#  {'Title': 'The Complete Frontend Developer Roadmap [2024]',
#   'Published_date': '2024-05-28T13:00:06Z',
#   'Views': '258200',
#   'Likes': '10122'},
#  {'Title': '9 Reasons People Hate JavaScript',
#   'Published_date': '2024-05-17T13:00:17Z',
#   'Views': '81829',
#   'Likes': '3264'},
#  {'Title': 'Become the React Dev Top Companies Want',
#   'Published_date': '2024-05-14T13:00:05Z',
#   'Views': '35943',
#   'Likes': '1267'},
#  {'Title': 'Stop Wasting Time on the Wrong Languages',
#   'Published_date': '2024-05-10T13:00:03Z',
#   'Views': '18100',
#   'Likes': '1154'},
#  {'Title': 'Is Coding Still Worth Learning in 2024?',
#   'Published_date': '2024-05-09T13:00:07Z',
#   'Views': '27978',
#   'Likes': '1050'},
#  {'Title': 'How to Get a Programming Job with No Experience',
#   'Published_date': '2024-05-08T13:01:00Z',
#   'Views': '20484',
#   'Likes': '1283'},
#  {'Title': 'Level Up Your VSCode Game: 5 Must-know Shortcuts',
#   'Published_date': '2024-05-07T13:00:01Z',
#   'Views': '40108',
#   'Likes': '2155'},
#  {'Title': 'Do you need a college degree to be a software engineer?',
#   'Published_date': '2024-05-03T13:00:11Z',
#   'Views': '16530',
#   'Likes': '1130'},
#  {'Title': "50 Hour Courses Are a SCAM! Here's Why...",
#   'Published_date': '2024-05-02T13:00:28Z',
#   'Views': '16153',
#   'Likes': '906'},
#  {'Title': 'Stop Wasting Time on the Wrong Languages',
#   'Published_date': '2024-04-30T13:00:07Z',
#   'Views': '68436',
#   'Likes': '3093'},
#  {'Title': "YouTube Tutorials Won't Get You Hired",
#   'Published_date': '2024-04-26T13:00:36Z',
#   'Views': '17800',
#   'Likes': '1249'},
#  {'Title': 'The FASTEST Way to Learn Coding & Get a Job',
#   'Published_date': '2024-04-25T13:00:42Z',
#   'Views': '25424',
#   'Likes': '1098'},
#  {'Title': '5 Mistakes That Are Killing Your Coding Progress',
#   'Published_date': '2024-04-24T13:01:01Z',
#   'Views': '59932',
#   'Likes': '3170'},
#  {'Title': 'What is Automated Testing',
#   'Published_date': '2024-04-23T13:00:17Z',
#   'Views': '10533',
#   'Likes': '550'},
#  {'Title': 'What is Unit Testing and Why You Must Learn It',
#   'Published_date': '2024-04-19T13:00:34Z',
#   'Views': '41387',
#   'Likes': '1412'},
#  {'Title': 'JavaScript in 2 Minutes',
#   'Published_date': '2024-04-18T13:00:36Z',
#   'Views': '50453',
#   'Likes': '1919'},
#  {'Title': 'Is Coding Still Worth Learning in 2024?',
#   'Published_date': '2024-04-17T13:00:07Z',
#   'Views': '333231',
#   'Likes': '10561'},
#  {'Title': 'Never Leave VSCode Again!',
#   'Published_date': '2024-04-16T13:00:23Z',
#   'Views': '19434',
#   'Likes': '861'},
#  {'Title': 'Python in 1 Minute',
#   'Published_date': '2024-04-13T14:00:19Z',
#   'Views': '117239',
#   'Likes': '6993'},
#  {'Title': 'Python in 2 Minutes!',
#   'Published_date': '2024-04-12T13:01:00Z',
#   'Views': '64569',
#   'Likes': '2154'},
#  {'Title': 'Mind-Blowing AI: This Tool Clones Voices Perfectly',
#   'Published_date': '2024-04-10T16:05:08Z',
#   'Views': '19765',
#   'Likes': '822'},
#  {'Title': 'Mind-Blowing AI:  This Tool Clones Voices Perfectly!',
#   'Published_date': '2024-04-10T13:15:03Z',
#   'Views': '11066',
#   'Likes': '403'},
#  {'Title': 'Did OpenAI Kill this Million-Dollar Business?',
#   'Published_date': '2024-04-10T13:00:06Z',
#   'Views': '20803',
#   'Likes': '966'},
#  {'Title': 'The FASTEST Way to Learn to Code & Get a Job',
#   'Published_date': '2024-04-09T13:00:06Z',
#   'Views': '125284',
#   'Likes': '6086'},
#  {'Title': 'This Robot Has a ChatGPT Brain!',
#   'Published_date': '2024-04-04T13:00:06Z',
#   'Views': '24763',
#   'Likes': '1083'},
#  {'Title': 'Top Programming Languages to Learn in 2024 (For High-paying Jobs)',
#   'Published_date': '2024-04-02T13:00:50Z',
#   'Views': '424033',
#   'Likes': '14578'},
#  {'Title': 'VSCode Trick: Stop Wasting Time Finding Files',
#   'Published_date': '2024-03-27T14:00:49Z',
#   'Views': '18676',
#   'Likes': '1060'},
#  {'Title': 'Endless YouTube Tutorials Are Wasting Your Time',
#   'Published_date': '2024-03-26T14:00:32Z',
#   'Views': '13649',
#   'Likes': '804'},
#  {'Title': '💥 VSCode Trick: Instantly Find Any Code',
#   'Published_date': '2024-03-21T14:00:23Z',
#   'Views': '21919',
#   'Likes': '1394'},
#  {'Title': 'Happy Nowruz!',
#   'Published_date': '2024-03-20T17:59:02Z',
#   'Views': '18893',
#   'Likes': '923'},
#  {'Title': 'Is Devin AI the End (or Future) of Coding?!',
#   'Published_date': '2024-03-20T13:00:06Z',
#   'Views': '477028',
#   'Likes': '8530'},
#  {'Title': 'Ignore the Coding Hype, Focus on What Pays',
#   'Published_date': '2024-03-19T14:00:29Z',
#   'Views': '24960',
#   'Likes': '2098'},
#  {'Title': "She Gave Up Her Coding Dreams... Don't Make the Same Mistake!",
#   'Published_date': '2024-03-18T14:00:45Z',
#   'Views': '17134',
#   'Likes': '1174'},
#  {'Title': 'Think JavaScript = Job?\xa0WRONG!',
#   'Published_date': '2024-03-15T14:00:44Z',
#   'Views': '19785',
#   'Likes': '1432'},
#  {'Title': 'Will Devin AI Replace Coders?',
#   'Published_date': '2024-03-14T14:00:06Z',
#   'Views': '207211',
#   'Likes': '8481'},
#  {'Title': 'The #1 Thing Slowing Your Coding Progress',
#   'Published_date': '2024-03-13T14:00:57Z',
#   'Views': '16674',
#   'Likes': '1166'},
#  {'Title': "Don't Let Ignorant CEOs Ruin Your Future (Coding Advice You Need)",
#   'Published_date': '2024-03-12T17:58:40Z',
#   'Views': '141877',
#   'Likes': '9012'},
#  {'Title': 'Level Up Your Coding Game with Multi-cursor Editing',
#   'Published_date': '2024-03-11T19:52:29Z',
#   'Views': '22771',
#   'Likes': '1701'},
#  {'Title': 'React Testing for Beginners: Start Here!',
#   'Published_date': '2024-02-27T13:00:09Z',
#   'Views': '116305',
#   'Likes': '2763'},
#  {'Title': 'New Course Coming Soon! #shorts',
#   'Published_date': '2024-02-22T18:41:22Z',
#   'Views': '16941',
#   'Likes': '1239'},
#  {'Title': 'JavaScript Unit Testing Tutorial for Beginners',
#   'Published_date': '2024-01-29T14:00:11Z',
#   'Views': '77875',
#   'Likes': '2327'},
#  {'Title': "Mosh's Christmas Present to You (2023)",
#   'Published_date': '2023-12-14T13:00:10Z',
#   'Views': '86309',
#   'Likes': '1482'},
#  {'Title': "Mosh's Black Friday Sale (2023)",
#   'Published_date': '2023-11-16T13:00:06Z',
#   'Views': '65712',
#   'Likes': '816'},
#  {'Title': 'The Most Hated React Code!',
#   'Published_date': '2023-10-31T13:00:09Z',
#   'Views': '44063',
#   'Likes': '1778'},
#  {'Title': 'Next.js Projects:  Build a Full-stack App with Next.js, Tailwind, Radix UI, and Prisma',
#   'Published_date': '2023-10-10T13:00:08Z',
#   'Views': '178697',
#   'Likes': '4044'},
#  {'Title': 'Next js Tutorial for Beginners | Nextjs 13 (App Router) with TypeScript',
#   'Published_date': '2023-09-11T13:00:10Z',
#   'Views': '709078',
#   'Likes': '15899'},
#  {'Title': 'New Next js Course Coming Soon!',
#   'Published_date': '2023-09-07T13:00:11Z',
#   'Views': '33158',
#   'Likes': '1501'},
#  {'Title': 'React Tutorial for Beginners',
#   'Published_date': '2023-03-12T08:00:07Z',
#   'Views': '3391833',
#   'Likes': '60686'},
#  {'Title': 'ChatGPT Tutorial for Developers - 38 Ways to 10x Your Productivity',
#   'Published_date': '2023-01-13T17:00:09Z',
#   'Views': '3565107',
#   'Likes': '54682'},
#  {'Title': "Mosh's Xmas gift to you!",
#   'Published_date': '2022-12-20T08:12:53Z',
#   'Views': '48988',
#   'Likes': '1332'},
#  {'Title': "Don't write code like John Smith!",
#   'Published_date': '2022-11-15T14:00:07Z',
#   'Views': '85782',
#   'Likes': '3374'},
#  {'Title': 'C++ Tutorial for Beginners - Learn C++ in 1 Hour',
#   'Published_date': '2022-08-10T16:00:12Z',
#   'Views': '4293449',
#   'Likes': '114920'},
#  {'Title': 'TypeScript Tutorial for Beginners',
#   'Published_date': '2022-05-23T13:00:18Z',
#   'Views': '1349098',
#   'Likes': '25653'},
#  {'Title': 'Docker Compose Tutorial',
#   'Published_date': '2022-03-22T14:00:12Z',
#   'Views': '457507',
#   'Likes': '7845'},
#  {'Title': 'Java Collections Tutorial',
#   'Published_date': '2022-03-01T14:00:18Z',
#   'Views': '193530',
#   'Likes': '3362'},
#  {'Title': 'Java Generics Tutorial',
#   'Published_date': '2022-02-22T14:00:07Z',
#   'Views': '64960',
#   'Likes': '1304'},
#  {'Title': 'Java Interfaces Tutorial',
#   'Published_date': '2022-02-15T14:00:06Z',
#   'Views': '75031',
#   'Likes': '1327'},
#  {'Title': 'Java Exception Handling Tutorial',
#   'Published_date': '2022-02-08T17:27:53Z',
#   'Views': '155636',
#   'Likes': '2047'},
#  {'Title': "Mosh's New Year's Gift to You!",
#   'Published_date': '2022-01-10T16:00:10Z',
#   'Views': '56408',
#   'Likes': '1477'},
#  {'Title': "Mosh's Xmas Gift (2021)",
#   'Published_date': '2021-12-20T23:02:36Z',
#   'Views': '82356',
#   'Likes': '2897'},
#  {'Title': '50% Off Black Friday Sale',
#   'Published_date': '2021-11-22T19:09:19Z',
#   'Views': '104778',
#   'Likes': '2872'},
#  {'Title': 'Python Django Tutorial for Beginners',
#   'Published_date': '2021-06-28T14:00:31Z',
#   'Views': '2720127',
#   'Likes': '46901'},
#  {'Title': 'Docker Tutorial for Beginners',
#   'Published_date': '2021-03-30T15:14:41Z',
#   'Views': '2669927',
#   'Likes': '45675'},
#  {'Title': 'Docker course is coming!',
#   'Published_date': '2021-03-25T17:30:03Z',
#   'Views': '46195',
#   'Likes': '2031'},
#  {'Title': 'HTML Tutorial for Beginners: HTML Crash Course',
#   'Published_date': '2021-01-11T14:30:10Z',
#   'Views': '9081151',
#   'Likes': '205184'},
#  {'Title': '5 Front-end Development Skills to Land Your First Job',
#   'Published_date': '2021-01-07T14:30:14Z',
#   'Views': '1500114',
#   'Likes': '66484'},
#  {'Title': 'Learn Web Development and Make $78,000/y',
#   'Published_date': '2021-01-05T14:30:11Z',
#   'Views': '226965',
#   'Likes': '11623'},
#  {'Title': "Mosh's Christmas Gift to You!",
#   'Published_date': '2020-12-22T00:41:01Z',
#   'Views': '84835',
#   'Likes': '2653'},
#  {'Title': 'What is Git? Explained in 2 Minutes!',
#   'Published_date': '2020-09-21T13:00:03Z',
#   'Views': '594390',
#   'Likes': '22207'},
#  {'Title': 'Python Machine Learning Tutorial (Data Science)',
#   'Published_date': '2020-09-17T13:00:03Z',
#   'Views': '2974546',
#   'Likes': '67328'},
#  {'Title': 'Python for Beginners - Learn Python in 1 Hour',
#   'Published_date': '2020-09-16T13:00:20Z',
#   'Views': '19278953',
#   'Likes': '457009'},
#  {'Title': 'Git Tutorial for Beginners: Learn Git in 1 Hour',
#   'Published_date': '2020-09-15T12:45:00Z',
#   'Views': '2569517',
#   'Likes': '49399'},
#  {'Title': 'Flutter vs React Native - Will Flutter Kill React Native?',
#   'Published_date': '2020-07-14T12:45:10Z',
#   'Views': '417120',
#   'Likes': '11900'},
#  {'Title': 'What Is React Native & Why Is It So Popular?',
#   'Published_date': '2020-07-06T13:00:13Z',
#   'Views': '252416',
#   'Likes': '7791'},
#  {'Title': 'Insertion Sort Algorithm Made Simple [Sorting Algorithms]',
#   'Published_date': '2020-06-29T13:00:11Z',
#   'Views': '306488',
#   'Likes': '6461'},
#  {'Title': 'Bubble Sort in Plain English',
#   'Published_date': '2020-06-22T13:00:10Z',
#   'Views': '169732',
#   'Likes': '4310'},
#  {'Title': 'React Native Tutorial for Beginners - Build a React Native App',
#   'Published_date': '2020-05-11T16:00:11Z',
#   'Views': '3201341',
#   'Likes': '50105'},
#  {'Title': 'Redux Tutorial - Learn Redux from Scratch',
#   'Published_date': '2020-04-20T16:00:13Z',
#   'Views': '1127400',
#   'Likes': '23629'},
#  {'Title': 'Top Programming Languages in 2020',
#   'Published_date': '2020-01-13T17:00:11Z',
#   'Views': '1182018',
#   'Likes': '28094'},
#  {'Title': 'Design Patterns in Plain English | Mosh Hamedani',
#   'Published_date': '2020-01-06T17:00:07Z',
#   'Views': '1410641',
#   'Likes': '28201'},
#  {'Title': 'Why I Left My Job as a Senior Software Engineer',
#   'Published_date': '2020-01-02T18:11:30Z',
#   'Views': '477803',
#   'Likes': '25154'},
#  {'Title': 'Jingle Bells Piano (Jazz) | Christmas Music',
#   'Published_date': '2019-12-25T20:22:29Z',
#   'Views': '29697',
#   'Likes': '1245'},
#  {'Title': "Mosh's Christmas Present to You (2019)",
#   'Published_date': '2019-12-16T04:48:49Z',
#   'Views': '154464',
#   'Likes': '2981'},
#  {'Title': 'Data Structures and Algorithms for Beginners',
#   'Published_date': '2019-12-10T17:00:02Z',
#   'Views': '1838204',
#   'Likes': '38823'},
#  {'Title': 'New Course: Data Structures & Algorithms [Part 2]',
#   'Published_date': '2019-09-07T19:46:52Z',
#   'Views': '39036',
#   'Likes': '834'},
#  {'Title': 'New Course: Data Structures and Algorithms Course',
#   'Published_date': '2019-08-20T18:04:34Z',
#   'Views': '84369',
#   'Likes': '2652'},
#  {'Title': 'Java Tutorial for Beginners',
#   'Published_date': '2019-07-15T16:00:12Z',
#   'Views': '11463618',
#   'Likes': '268814'},
#  {'Title': 'React vs Angular vs Vue: What to Choose for Your Next Project',
#   'Published_date': '2019-05-09T21:08:25Z',
#   'Views': '193291',
#   'Likes': '5259'},
#  {'Title': 'React vs Angular vs Vue: What to Learn to Get a Front-end Job',
#   'Published_date': '2019-04-17T16:00:06Z',
#   'Views': '443050',
#   'Likes': '7746'},
#  {'Title': 'SQL Tutorial for Beginners [Full Course]',
#   'Published_date': '2019-03-20T00:50:32Z',
#   'Views': '12045454',
#   'Likes': '254265'},
#  {'Title': 'Python Tutorial - Python Full Course for Beginners',
#   'Published_date': '2019-02-18T15:00:08Z',
#   'Views': '41568647',
#   'Likes': '1130436'},
#  {'Title': 'How to Learn to Code and Make $60k+ a Year',
#   'Published_date': '2019-01-08T21:43:10Z',
#   'Views': '2316663',
#   'Likes': '97033'},
#  {'Title': "Mosh's Xmas Present 2018",
#   'Published_date': '2018-12-16T19:26:17Z',
#   'Views': '69522',
#   'Likes': '1814'},
#  {'Title': 'Python Practice - Interview Question - Fizz Buzz | Mosh',
#   'Published_date': '2018-11-19T15:00:12Z',
#   'Views': '96638',
#   'Likes': '1779'},
#  {'Title': 'How to Sort Lists in Python - Python Tutorial for Absolute Beginners | Mosh',
#   'Published_date': '2018-11-16T15:00:00Z',
#   'Views': '103144',
#   'Likes': '1616'},
#  {'Title': 'Map and Filter Functions in Python - Python Tutorial for Absolute Beginners | Mosh',
#   'Published_date': '2018-11-15T15:00:00Z',
#   'Views': '63758',
#   'Likes': '1213'},
#  {'Title': 'Programming with Mosh Live Stream',
#   'Published_date': '2018-11-14T22:33:43Z',
#   'Views': '0',
#   'Likes': '0'},
#  {'Title': 'What are Sets in Python? Python Tutorial for Absolute Beginners | Mosh',
#   'Published_date': '2018-11-14T15:00:05Z',
#   'Views': '89255',
#   'Likes': '1919'},
#  {'Title': "Mosh's Black Friday Sales (2018)",
#   'Published_date': '2018-11-14T02:43:55Z',
#   'Views': '233136',
#   'Likes': '843'},
#  {'Title': 'Python Stacks - Python Tutorial for Absolute Beginners | Mosh',
#   'Published_date': '2018-11-13T15:00:02Z',
#   'Views': '149836',
#   'Likes': '2596'},
#  {'Title': 'Python Variables - Python Tutorial for Beginners with Examples | Mosh',
#   'Published_date': '2018-11-12T15:00:02Z',
#   'Views': '195826',
#   'Likes': '3127'},
#  {'Title': 'How to Use Strings in Python - Python Tutorial for Beginners',
#   'Published_date': '2018-11-09T15:00:01Z',
#   'Views': '241015',
#   'Likes': '4130'},
#  {'Title': 'How to Use Lists in Python',
#   'Published_date': '2018-11-08T15:00:00Z',
#   'Views': '315773',
#   'Likes': '5795'},
#  {'Title': 'Control Flow in Python - If Elif Else Statements',
#   'Published_date': '2018-11-06T20:30:54Z',
#   'Views': '303118',
#   'Likes': '5457'},
#  {'Title': 'Python Functions | Python Tutorial for Absolute Beginners #1',
#   'Published_date': '2018-11-06T15:00:11Z',
#   'Views': '979400',
#   'Likes': '17651'},
#  {'Title': 'Python For Loops - Python Tutorial for Absolute Beginners',
#   'Published_date': '2018-11-05T15:00:00Z',
#   'Views': '614424',
#   'Likes': '11004'},
#  {'Title': 'Python Exercises for Beginners - Exercise #1',
#   'Published_date': '2018-11-04T00:30:00Z',
#   'Views': '348985',
#   'Likes': '5040'},
#  {'Title': 'How to Loop over Lists in Python',
#   'Published_date': '2018-11-04T00:00:00Z',
#   'Views': '147980',
#   'Likes': '1567'},
#  {'Title': 'Stop Wasting Your Time and Money at Universities!',
#   'Published_date': '2018-10-31T02:48:51Z',
#   'Views': '1118219',
#   'Likes': '8600'},
#  {'Title': 'What is Python? Why Python is So Popular?',
#   'Published_date': '2018-10-23T03:06:02Z',
#   'Views': '2020327',
#   'Likes': '64933'},
#  {'Title': 'Learn Python Programming - Python Course',
#   'Published_date': '2018-10-22T14:00:07Z',
#   'Views': '987473',
#   'Likes': '16147'},
#  {'Title': 'Python Tutorials for Beginners - Learn Python Online',
#   'Published_date': '2018-10-22T14:00:05Z',
#   'Views': '1124823',
#   'Likes': '20138'},
#  {'Title': 'React JS - React Tutorial for Beginners',
#   'Published_date': '2018-07-16T16:51:44Z',
#   'Views': '6204014',
#   'Likes': '92978'},
#  {'Title': 'ES6 Tutorial: Learn Modern JavaScript in 1 Hour',
#   'Published_date': '2018-06-29T19:50:21Z',
#   'Views': '1001674',
#   'Likes': '21325'},
#  {'Title': 'What Is React (React js) & Why Is It So Popular?',
#   'Published_date': '2018-06-27T04:05:47Z',
#   'Views': '869360',
#   'Likes': '17358'},
#  {'Title': 'My Brand New JavaScript Course',
#   'Published_date': '2018-05-16T17:41:30Z',
#   'Views': '44332',
#   'Likes': '469'},
#  {'Title': 'JavaScript Bitwise Operators',
#   'Published_date': '2018-05-15T22:54:54Z',
#   'Views': '102112',
#   'Likes': '2595'},
#  {'Title': 'JavaScript Let vs Var vs Constant | Mosh',
#   'Published_date': '2018-05-15T22:52:37Z',
#   'Views': '289678',
#   'Likes': '6113'},
#  {'Title': 'JavaScript Array Reduce',
#   'Published_date': '2018-05-15T22:51:34Z',
#   'Views': '339385',
#   'Likes': '8646'},
#  {'Title': 'JavaScript Array Map',
#   'Published_date': '2018-05-15T22:50:37Z',
#   'Views': '363886',
#   'Likes': '4942'},
#  {'Title': 'JavaScript Array Filter',
#   'Published_date': '2018-05-15T22:50:00Z',
#   'Views': '188168',
#   'Likes': '2930'},
#  {'Title': 'JavaScript Template Literals',
#   'Published_date': '2018-05-15T22:49:15Z',
#   'Views': '129308',
#   'Likes': '2623'},
#  {'Title': 'JavaScript Strings',
#   'Published_date': '2018-05-15T22:48:37Z',
#   'Views': '131754',
#   'Likes': '1556'},
#  {'Title': 'JavaScript this Keyword',
#   'Published_date': '2018-05-15T22:47:58Z',
#   'Views': '461956',
#   'Likes': '11413'},
#  {'Title': 'JavaScript Cloning an Object',
#   'Published_date': '2018-05-15T22:40:56Z',
#   'Views': '85601',
#   'Likes': '1281'},
#  {'Title': 'JavaScript Scope (Local vs Global)',
#   'Published_date': '2018-05-15T22:38:29Z',
#   'Views': '58237',
#   'Likes': '1101'},
#  {'Title': 'JavaScript Value vs Reference Types',
#   'Published_date': '2018-05-15T22:36:51Z',
#   'Views': '99306',
#   'Likes': '2245'},
#  {'Title': 'JavaScript Functions',
#   'Published_date': '2018-05-15T22:35:35Z',
#   'Views': '442313',
#   'Likes': '7648'},
#  {'Title': 'JavaScript Getters and Setters | Mosh',
#   'Published_date': '2018-05-15T22:34:23Z',
#   'Views': '242041',
#   'Likes': '6401'},
#  {'Title': 'JavaScript Arrays',
#   'Published_date': '2018-05-15T22:33:18Z',
#   'Views': '296773',
#   'Likes': '3476'},
#  {'Title': 'JavaScript Loops',
#   'Published_date': '2018-05-15T22:32:25Z',
#   'Views': '428049',
#   'Likes': '7978'},
#  {'Title': 'JavaScript Constructor Functions',
#   'Published_date': '2018-05-15T22:30:14Z',
#   'Views': '249182',
#   'Likes': '4376'},
#  {'Title': 'JavaScript Factory Functions',
#   'Published_date': '2018-05-15T22:28:47Z',
#   'Views': '153553',
#   'Likes': '2286'},
#  {'Title': 'JavaScript if else (tutorial)',
#   'Published_date': '2018-05-15T22:27:15Z',
#   'Views': '348941',
#   'Likes': '4530'},
#  {'Title': 'What is JavaScript?',
#   'Published_date': '2018-04-24T04:00:17Z',
#   'Views': '819179',
#   'Likes': '11428'},
#  {'Title': 'JavaScript Tutorial for Beginners: Learn JavaScript in 1 Hour',
#   'Published_date': '2018-04-24T02:37:33Z',
#   'Views': '13313944',
#   'Likes': '230951'},
#  {'Title': 'Object-oriented Programming in JavaScript: Made Super Simple | Mosh',
#   'Published_date': '2018-03-30T00:30:46Z',
#   'Views': '1998114',
#   'Likes': '41917'},
#  {'Title': 'Object-oriented Programming in 7 minutes | Mosh',
#   'Published_date': '2018-03-30T00:24:17Z',
#   'Views': '4069099',
#   'Likes': '101726'},
#  {'Title': 'How to build a REST API with Node js & Express',
#   'Published_date': '2018-03-08T22:21:57Z',
#   'Views': '1795161',
#   'Likes': '29474'},
#  {'Title': 'Node.js Tutorial for Beginners: Learn Node in 1 Hour',
#   'Published_date': '2018-02-21T23:57:12Z',
#   'Views': '5887194',
#   'Likes': '93639'},
#  {'Title': 'HTTP Module in Node.js',
#   'Published_date': '2018-02-16T02:30:00Z',
#   'Views': '94265',
#   'Likes': '1273'},
#  {'Title': 'Extending the Event Emitter',
#   'Published_date': '2018-02-15T02:30:00Z',
#   'Views': '40306',
#   'Likes': '646'},
#  {'Title': 'Event Arguments',
#   'Published_date': '2018-02-13T23:00:02Z',
#   'Views': '23801',
#   'Likes': '294'},
#  {'Title': 'Events and Event Emitter in Node.js',
#   'Published_date': '2018-02-12T21:00:05Z',
#   'Views': '126236',
#   'Likes': '2683'},
#  {'Title': 'OS Module in Node.js',
#   'Published_date': '2018-02-11T19:00:01Z',
#   'Views': '26565',
#   'Likes': '296'},
#  {'Title': 'Path Module in Node.js',
#   'Published_date': '2018-02-10T22:00:01Z',
#   'Views': '58929',
#   'Likes': '561'},
#  {'Title': 'Module Wrapper Function',
#   'Published_date': '2018-02-09T18:00:02Z',
#   'Views': '44938',
#   'Likes': '434'},
#  {'Title': 'Loading (Requiring) a Module in Node.js',
#   'Published_date': '2018-02-08T21:00:01Z',
#   'Views': '36567',
#   'Likes': '412'},
#  {'Title': 'Creating a Module in Node.js',
#   'Published_date': '2018-02-07T18:00:01Z',
#   'Views': '77987',
#   'Likes': '773'},
#  {'Title': 'Modules in Node.js',
#   'Published_date': '2018-02-07T02:36:48Z',
#   'Views': '80466',
#   'Likes': '898'},
#  {'Title': 'Globals in Node.js',
#   'Published_date': '2018-02-02T18:17:51Z',
#   'Views': '54874',
#   'Likes': '525'},
#  {'Title': 'Your First Node App',
#   'Published_date': '2018-02-01T21:00:25Z',
#   'Views': '54457',
#   'Likes': '473'},
#  {'Title': 'Installing Node.js',
#   'Published_date': '2018-02-01T20:59:03Z',
#   'Views': '76015',
#   'Likes': '516'},
#  {'Title': 'How Node.js Works | Mosh',
#   'Published_date': '2018-01-25T22:28:45Z',
#   'Views': '348155',
#   'Likes': '6526'},
#  {'Title': 'Node.js Architecture | Mosh',
#   'Published_date': '2018-01-25T00:09:12Z',
#   'Views': '164270',
#   'Likes': '2394'},
#  {'Title': 'What is Node js?',
#   'Published_date': '2018-01-23T23:51:31Z',
#   'Views': '876398',
#   'Likes': '12274'},
#  {'Title': 'What is a REST API?',
#   'Published_date': '2018-01-20T00:09:55Z',
#   'Views': '783268',
#   'Likes': '18674'},
#  {'Title': '$50 All-Access Mosh in 2018',
#   'Published_date': '2017-12-18T22:00:03Z',
#   'Views': '127896',
#   'Likes': '1018'},
#  {'Title': 'What is MVVM (Model-View-ViewModel) Pattern?',
#   'Published_date': '2017-11-14T21:11:40Z',
#   'Views': '331143',
#   'Likes': '2555'},
#  {'Title': 'C# Access Modifiers: What They Are and Why We Need Them',
#   'Published_date': '2017-11-08T20:43:24Z',
#   'Views': '108948',
#   'Likes': '1447'},
#  {'Title': 'C# Interfaces Explained in Simple Terms | Mosh',
#   'Published_date': '2017-11-08T20:32:06Z',
#   'Views': '249045',
#   'Likes': '2439'},
#  {'Title': 'C# Methods Tutorial | Mosh',
#   'Published_date': '2017-11-08T19:02:58Z',
#   'Views': '116700',
#   'Likes': '1269'},
#  {'Title': 'C# Fields Tutorial',
#   'Published_date': '2017-11-08T19:00:32Z',
#   'Views': '78344',
#   'Likes': '889'},
#  {'Title': 'C# Constructors Tutorial | Mosh',
#   'Published_date': '2017-11-08T19:00:03Z',
#   'Views': '238137',
#   'Likes': '3905'},
#  {'Title': 'C# Object Initializers Tutorial',
#   'Published_date': '2017-11-08T18:55:21Z',
#   'Views': '70098',
#   'Likes': '801'},
#  {'Title': 'C# Classes Tutorial | Mosh',
#   'Published_date': '2017-11-08T18:49:27Z',
#   'Views': '283857',
#   'Likes': '3662'},
#  {'Title': 'Unit Testing C# Code - Tutorial for Beginners',
#   'Published_date': '2017-11-07T19:46:38Z',
#   'Views': '610266',
#   'Likes': '8272'},
#  {'Title': '[NEW COURSE] Unit Testing for C# Developers',
#   'Published_date': '2017-10-27T19:44:12Z',
#   'Views': '11896',
#   'Likes': '98'},
#  {'Title': 'Angular 4 in 40 Minutes',
#   'Published_date': '2017-09-28T19:30:01Z',
#   'Views': '30761',
#   'Likes': '489'},
#  {'Title': 'Routing and Navigation in Angular | Mosh',
#   'Published_date': '2017-09-06T21:44:09Z',
#   'Views': '285286',
#   'Likes': '3850'},
#  {'Title': 'Directives in Angular Applications',
#   'Published_date': '2017-09-06T21:32:25Z',
#   'Views': '181283',
#   'Likes': '2545'},
#  {'Title': 'Building Forms in Angular Apps | Mosh',
#   'Published_date': '2017-09-06T21:28:58Z',
#   'Views': '419273',
#   'Likes': '5932'},
#  {'Title': 'Deploying Angular Applications | Mosh',
#   'Published_date': '2017-09-06T21:26:17Z',
#   'Views': '126482',
#   'Likes': '1864'},
#  {'Title': 'Firebase in Angular Applications | Mosh',
#   'Published_date': '2017-09-06T21:21:38Z',
#   'Views': '144589',
#   'Likes': '2298'},
#  {'Title': 'Angular Animations Tutorial | Mosh',
#   'Published_date': '2017-09-06T21:15:00Z',
#   'Views': '157788',
#   'Likes': '2549'},
#  {'Title': 'Angular Material Tutorial | Mosh',
#   'Published_date': '2017-09-06T21:08:27Z',
#   'Views': '264424',
#   'Likes': '3649'},
#  {'Title': 'AngularJS vs Angular 2 vs Angular 4 | Mosh',
#   'Published_date': '2017-09-06T20:56:00Z',
#   'Views': '82821',
#   'Likes': '1503'},
#  {'Title': 'Angular Tutorial for Beginners: Learn Angular & TypeScript',
#   'Published_date': '2017-09-05T16:48:15Z',
#   'Views': '4491831',
#   'Likes': '63621'},
#  {'Title': 'TypeScript Properties',
#   'Published_date': '2017-09-04T21:30:03Z',
#   'Views': '10733',
#   'Likes': '120'},
#  {'Title': 'TypeScript Constructors',
#   'Published_date': '2017-09-04T21:30:01Z',
#   'Views': '23614',
#   'Likes': '283'},
#  {'Title': 'TypeScript Interfaces',
#   'Published_date': '2017-09-04T21:30:00Z',
#   'Views': '29342',
#   'Likes': '468'},
#  {'Title': 'TypeScript Classes',
#   'Published_date': '2017-09-04T21:30:00Z',
#   'Views': '13782',
#   'Likes': '145'},
#  {'Title': 'Access Modifiers in TypeScript',
#   'Published_date': '2017-09-04T19:30:00Z',
#   'Views': '20901',
#   'Likes': '265'},
#  {'Title': 'TypeScript Tutorial - TypeScript for React - Learn TypeScript',
#   'Published_date': '2017-08-31T19:25:02Z',
#   'Views': '599281',
#   'Likes': '10850'},
#  {'Title': 'My Brand New Angular Course',
#   'Published_date': '2017-08-31T00:18:03Z',
#   'Views': '19019',
#   'Likes': '238'},
#  {'Title': 'Demo of An E-commerce App Built with Angular, Firebase and Bootstrap 4',
#   'Published_date': '2017-08-30T23:44:44Z',
#   'Views': '99300',
#   'Likes': '729'},
#  {'Title': 'Udemy Live 2017: Teaching Tech Panel',
#   'Published_date': '2017-08-03T03:21:20Z',
#   'Views': '37178',
#   'Likes': '718'},
#  {'Title': 'Two-way Binding and ngModel in Angular 4',
#   'Published_date': '2017-06-15T23:30:28Z',
#   'Views': '93551',
#   'Likes': '708'},
#  {'Title': 'Entity Framework 6 Tutorial: Learn Entity Framework 6 from Scratch',
#   'Published_date': '2017-04-13T09:38:28Z',
#   'Views': '523405',
#   'Likes': '5201'},
#  {'Title': 'Build a Real-world App with ASP.NET Core and Angular 2',
#   'Published_date': '2017-03-19T03:21:40Z',
#   'Views': '169917',
#   'Likes': '1271'},
#  {'Title': 'Profile and optimize your Angular 2 apps',
#   'Published_date': '2017-02-13T09:18:16Z',
#   'Views': '29629',
#   'Likes': '442'},
#  {'Title': 'Testing Angular 2+ Apps with Jasmine and Karma | Mosh',
#   'Published_date': '2017-02-02T09:17:55Z',
#   'Views': '333025',
#   'Likes': '3923'},
#  {'Title': 'Using Redux in Angular 2+ Apps | Mosh',
#   'Published_date': '2017-01-24T05:15:19Z',
#   'Views': '128569',
#   'Likes': '1698'},
#  {'Title': 'Value Types and Reference Types in JavaScript',
#   'Published_date': '2017-01-17T05:32:08Z',
#   'Views': '16496',
#   'Likes': '566'},
#  {'Title': 'Xamarin Forms Tutorial: Build Native Mobile Apps with C#',
#   'Published_date': '2016-12-21T23:48:15Z',
#   'Views': '945480',
#   'Likes': '10274'},
#  {'Title': '[Pluralsight]: Become a Full-stack .NET Developer',
#   'Published_date': '2016-06-13T11:38:09Z',
#   'Views': '143013',
#   'Likes': '1213'},
#  {'Title': 'Step-by-step ASP.NET MVC Tutorial for Beginners | Mosh',
#   'Published_date': '2016-05-29T05:26:02Z',
#   'Views': '3619885',
#   'Likes': '37758'},
#  {'Title': 'Difference between Junior and Senior Developers',
#   'Published_date': '2016-05-10T07:26:53Z',
#   'Views': '72127',
#   'Likes': '1749'},
#  {'Title': 'C# Tutorial For Beginners - Learn C# Basics in 1 Hour',
#   'Published_date': '2016-04-03T07:02:55Z',
#   'Views': '5122444',
#   'Likes': '76604'},
#  {'Title': 'Working with Components in Angular',
#   'Published_date': '2016-03-22T07:36:03Z',
#   'Views': '22815',
#   'Likes': '96'},
#  {'Title': 'Architecture of Angular 2+ Apps',
#   'Published_date': '2016-03-22T06:52:57Z',
#   'Views': '24953',
#   'Likes': '209'},
#  {'Title': 'Angular 2 Tutorial for Beginners: Learn Angular 2 from Scratch | Mosh',
#   'Published_date': '2016-03-04T12:12:52Z',
#   'Views': '1049905',
#   'Likes': '9936'},
#  {'Title': 'Repository Pattern with C# and Entity Framework, Done Right | Mosh',
#   'Published_date': '2015-10-15T11:39:54Z',
#   'Views': '874140',
#   'Likes': '12477'},
#  {'Title': 'Debugging C# Code in Visual Studio | Mosh',
#   'Published_date': '2015-09-16T09:16:21Z',
#   'Views': '380578',
#   'Likes': '3744'},
#  {'Title': 'C# Generics Tutorial: Whats and Whys | Mosh',
#   'Published_date': '2015-05-02T05:27:16Z',
#   'Views': '262103',
#   'Likes': '3350'},
#  {'Title': 'C# Events and Delegates Made Simple | Mosh',
#   'Published_date': '2014-11-17T11:54:57Z',
#   'Views': '949889',
#   'Likes': '18316'},
#  {'Title': 'Clean Code: Learn to write clean, maintainable and robust code',
#   'Published_date': '2014-11-15T11:04:08Z',
#   'Views': '362861',
#   'Likes': '3561'},
#  {'Title': 'Backbone.js Tutorial Part 14 - Backbone.js Views: Templating',
#   'Published_date': '2014-10-23T12:18:24Z',
#   'Views': '12955',
#   'Likes': '103'},
#  {'Title': 'Backbone.js Tutorial Part 13 - Backbone.js Views: Handling Collection Events',
#   'Published_date': '2014-10-22T11:53:16Z',
#   'Views': '4817',
#   'Likes': '34'},
#  {'Title': 'Backbone.js Tutorial Part 12 - Backbone.js Views: Handling the Model Events',
#   'Published_date': '2014-10-21T10:25:52Z',
#   'Views': '10820',
#   'Likes': '60'},
#  {'Title': 'Backbone.js Tutorial Part 11 - Backbone.js Views: Handling the DOM Events',
#   'Published_date': '2014-10-20T12:15:10Z',
#   'Views': '10459',
#   'Likes': '50'},
#  {'Title': 'Backbone.js Tutorial Part 10 - Backbone.js Views: Passing Data to Views',
#   'Published_date': '2014-10-16T11:09:05Z',
#   'Views': '14368',
#   'Likes': '93'},
#  {'Title': 'Backbone.js Tutorial Part 9 - Backbone.js Views: Creating Views',
#   'Published_date': '2014-10-14T10:31:25Z',
#   'Views': '17694',
#   'Likes': '113'},
#  {'Title': 'Backbone.js Tutorial Part 8 - Backbone.js Collections: Fetching Collections from the Server',
#   'Published_date': '2014-10-13T11:19:19Z',
#   'Views': '12874',
#   'Likes': '58'},
#  {'Title': 'Backbone.js Tutorial Part 7 - Backbone.js Collections: Working with Collections',
#   'Published_date': '2014-10-12T08:21:30Z',
#   'Views': '3904',
#   'Likes': '34'},
#  {'Title': 'Backbone.js Tutorial Part 6 - Backbone.js Collections: Creating Collections',
#   'Published_date': '2014-10-11T08:08:09Z',
#   'Views': '14856',
#   'Likes': '80'},
#  {'Title': 'Backbone.js Tutorial Part 5 - Backbone.js Models: Syncing Models with the Server',
#   'Published_date': '2014-10-10T00:14:33Z',
#   'Views': '17800',
#   'Likes': '103'},
#  {'Title': 'Backbone.js Tutorial Part 1 - Backbone.js Models: Creating Models',
#   'Published_date': '2014-10-09T12:36:50Z',
#   'Views': '65117',
#   'Likes': '207'},
#  {'Title': 'Backbone.js Tutorial Part 4 - Backbone.js Models: Model Inheritance',
#   'Published_date': '2014-10-09T12:33:33Z',
#   'Views': '14084',
#   'Likes': '68'},
#  {'Title': 'Backbone.js Tutorial Part 3 - Backbone.js Models: Model Validation',
#   'Published_date': '2014-10-09T12:24:24Z',
#   'Views': '15916',
#   'Likes': '81'},
#  {'Title': 'Backbone.js Tutorial Part 2 - Backbone.js Models: Working with Model Attributes',
#   'Published_date': '2014-10-09T12:24:02Z',
#   'Views': '26219',
#   'Likes': '134'},
#  {'Title': 'Visual Studio Keyboard Shortcuts that Speed Up Debugging Applications | Mosh',
#   'Published_date': '2014-10-07T09:51:45Z',
#   'Views': '82161',
#   'Likes': '846'},
#  {'Title': '6 Visual Studio Tips to Increase Your Productivity | Mosh',
#   'Published_date': '2014-10-07T02:35:37Z',
#   'Views': '558485',
#   'Likes': '7273'}]

# %%
Video_data=pd.DataFrame(Video_details)

Video_data['Published_date'] =pd.to_datetime(Video_data['Published_date']).dt.date#remove timestamp for publication and only leaves date
Video_data['Views']= pd.to_numeric(Video_data['Views'])#changes the following to numeric values instead of string
Video_data['Likes']= pd.to_numeric(Video_data['Likes'])
#Video_data['Comments']= pd.to_numeric(Video_data['Comments'])

Video_data
# Out:
#                                                  Title Published_date   Views  \
# 0    Python Projects for Beginners – Master Problem...     2024-09-10   89884
# 1        Big Update: Watch My Videos in Your Language!     2024-09-09   29155
# 2    Get Ready for Something Special – Announcement...     2024-09-06   23943
# 3                   The Complete DevOps Roadmap [2024]     2024-08-15  152186
# 4             The Complete Data Analyst Roadmap [2024]     2024-08-06  126569
# ..                                                 ...            ...     ...
# 231  Backbone.js Tutorial Part 4 - Backbone.js Mode...     2014-10-09   14084
# 232  Backbone.js Tutorial Part 3 - Backbone.js Mode...     2014-10-09   15916
# 233  Backbone.js Tutorial Part 2 - Backbone.js Mode...     2014-10-09   26219
# 234  Visual Studio Keyboard Shortcuts that Speed Up...     2014-10-07   82161
# 235  6 Visual Studio Tips to Increase Your Producti...     2014-10-07  558485
#
#      Likes
# 0     3433
# 1     1073
# 2     1247
# 3     5386
# 4     4201
# ..     ...
# 231     68
# 232     81
# 233    134
# 234    846
# 235   7273
#
# [236 rows x 4 columns]

# %%
Top_videos = Video_data.sort_values(by='Views', ascending=False)#add .head(x) to cap the number of videos

Top_videos #Outputs videos based on views
# Out:
#                                                  Title Published_date  \
# 103  Python Tutorial - Python Full Course for Begin...     2019-02-18
# 83       Python for Beginners - Learn Python in 1 Hour     2020-09-16
# 148  JavaScript Tutorial for Beginners: Learn JavaS...     2018-04-24
# 102           SQL Tutorial for Beginners [Full Course]     2019-03-20
# 99                         Java Tutorial for Beginners     2019-07-15
# ..                                                 ...            ...
# 26                           What is Automated Testing     2024-04-23
# 223  Backbone.js Tutorial Part 11 - Backbone.js Vie...     2014-10-20
# 221  Backbone.js Tutorial Part 13 - Backbone.js Vie...     2014-10-22
# 227  Backbone.js Tutorial Part 7 - Backbone.js Coll...     2014-10-12
# 109                  Programming with Mosh Live Stream     2018-11-14
#
#         Views    Likes
# 103  41568647  1130436
# 83   19278953   457009
# 148  13313944   230951
# 102  12045454   254265
# 99   11463618   268814
# ..        ...      ...
# 26      10533      550
# 223     10459       50
# 221      4817       34
# 227      3904       34
# 109         0        0
#
# [236 rows x 4 columns]

# %%
#Top_videos.to_csv('Video_Details(Khan Academy).csv')
